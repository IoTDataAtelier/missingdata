# %%
import os
import sys
import pandas as pd
from IPython.display import display, HTML
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %% [markdown]
# <h2>Loading dataset</h2>

# %%
from pypotsModify.benchpots.datasets import preprocess_physionet2012
physionet2012_dataset = preprocess_physionet2012(subset="all", rate=0.1)
# Out:
# 2024-11-28 23:25:20 [INFO]: You're using dataset physionet_2012, please cite it properly in your work. You can find its reference information at the below link:
# https://github.com/WenjieDu/TSDB/tree/main/dataset_profiles/physionet_2012
# 2024-11-28 23:25:20 [INFO]: Dataset physionet_2012 has already been downloaded. Processing directly...
# 2024-11-28 23:25:20 [INFO]: Dataset physionet_2012 has already been cached. Loading from cache directly...
# 2024-11-28 23:25:21 [INFO]: Loaded successfully!

# %% [markdown]
# <h3>Training data</h3>

# %% [markdown]
# <h4>Loading training dataset</h4>

# %%
train_X = physionet2012_dataset['train_X']

# %%
training_female_gender = train_X[train_X["Gender"] == 0.0]
training_female_gender_ids = training_female_gender["RecordID"]
female_gender_measurements_training = train_X[train_X["RecordID"].isin(training_female_gender_ids)]
female_gender_measurements_training = female_gender_measurements_training.count()
female_gender_measurements_training
# Out:
# RecordID       163728
# level_1        163728
# Time           163728
# ALP              2565
# ALT              2646
# AST              2641
# Age            154147
# Albumin          2061
# BUN             11780
# Bilirubin        2687
# Cholesterol       270
# Creatinine      11829
# DiasABP         83387
# FiO2            25129
# GCS             53030
# Gender           3411
# Glucose         11214
# HCO3            11573
# HCT             14996
# HR             148057
# Height         154147
# ICUType          3411
# K               12443
# Lactate          6358
# MAP             82890
# MechVent        24446
# Mg              11536
# NIDiasABP       72980
# NIMAP           71854
# NISysABP        73033
# Na              11662
# PaCO2           17290
# PaO2            17266
# Platelets       11616
# RespRate        43867
# SaO2             6069
# SysABP          83393
# Temp            58295
# TroponinI         379
# TroponinT        1744
# Urine          113878
# WBC             10811
# Weight          87627
# pH              17932
# dtype: int64

# %%
training_male_gender = train_X[train_X['Gender'] == 1.0]
training_male_gender_ids = training_male_gender["RecordID"]
male_gender_measurements_training = train_X[train_X["RecordID"].isin(training_male_gender_ids)]
male_gender_measurements_training  = male_gender_measurements_training.count()
male_gender_measurements_training
# Out:
# RecordID       204000
# level_1        204000
# Time           204000
# ALP              3361
# ALT              3456
# AST              3460
# Age            192371
# Albumin          2546
# BUN             14864
# Bilirubin        3499
# Cholesterol       371
# Creatinine      14955
# DiasABP        114687
# FiO2            32714
# GCS             65350
# Gender           4250
# Glucose         13932
# HCO3            14507
# HCT             19981
# HR             183886
# Height         192371
# ICUType          4250
# K               15571
# Lactate          8748
# MAP            113984
# MechVent        30917
# Mg              14551
# NIDiasABP       83038
# NIMAP           82009
# NISysABP        83105
# Na              14480
# PaCO2           24841
# PaO2            24797
# Platelets       15441
# RespRate        44898
# SaO2             8504
# SysABP         114694
# Temp            78366
# TroponinI         407
# TroponinT        2249
# Urine          141347
# WBC             13891
# Weight         107207
# pH              26101
# dtype: int64

# %%
training_undefined_gender = train_X[train_X['Gender'] == -1.0]
undefined_gender_training_ids = training_undefined_gender['RecordID']
undefined_gender_measurements_training = train_X[train_X["RecordID"].isin(undefined_gender_training_ids)]
undefined_gender_measurements_training = undefined_gender_measurements_training.count()
undefined_gender_measurements_training
# Out:
# RecordID       480
# level_1        480
# Time           480
# ALP              3
# ALT              4
# AST              4
# Age            335
# Albumin          2
# BUN             24
# Bilirubin        3
# Cholesterol      0
# Creatinine      24
# DiasABP        242
# FiO2            32
# GCS            107
# Gender          10
# Glucose         24
# HCO3            24
# HCT             23
# HR             319
# Height         335
# ICUType         10
# K               25
# Lactate          3
# MAP            236
# MechVent        28
# Mg              23
# NIDiasABP      138
# NIMAP          138
# NISysABP       138
# Na              23
# PaCO2           25
# PaO2            25
# Platelets       22
# RespRate       135
# SaO2             1
# SysABP         242
# Temp           117
# TroponinI        1
# TroponinT        7
# Urine          225
# WBC             22
# Weight         210
# pH              30
# dtype: int64

# %%
training_ICUType_1 = train_X[train_X['ICUType'] == 1.0]
training_ICUType_1 = training_ICUType_1[training_ICUType_1["Time"] == 0.0]
training_ICUType_1_ids = training_ICUType_1["RecordID"]
ICUType_1_measurements_training = train_X[train_X["RecordID"].isin(training_ICUType_1_ids)]
ICUType_1_measurements_training = ICUType_1_measurements_training.count() 
ICUType_1_measurements_training
# Out:
# RecordID       52656
# level_1        52656
# Time           52656
# ALP              787
# ALT              829
# AST              828
# Age            48181
# Albumin          595
# BUN             3728
# Bilirubin        822
# Cholesterol      343
# Creatinine      3799
# DiasABP        21469
# FiO2            5640
# GCS            13529
# Gender          1097
# Glucose         3572
# HCO3            3599
# HCT             4630
# HR             45799
# Height         48181
# ICUType         1097
# K               4366
# Lactate         1177
# MAP            21342
# MechVent        5240
# Mg              3714
# NIDiasABP      25526
# NIMAP          25419
# NISysABP       25544
# Na              3575
# PaCO2           4302
# PaO2            4301
# Platelets       3787
# RespRate       18654
# SaO2            2547
# SysABP         21470
# Temp           15787
# TroponinI        163
# TroponinT       1117
# Urine          30111
# WBC             3365
# Weight         23714
# pH              4404
# dtype: int64

# %%
training_ICUType_2 = train_X[train_X['ICUType'] == 2.0]
training_ICUType_2 = training_ICUType_2[training_ICUType_2["Time"] == 0.0]
training_ICUType2_ids = training_ICUType_2["RecordID"]
ICUType_2_measurements_training = train_X[train_X["RecordID"].isin(training_ICUType2_ids)]
ICUType_2_measurements_training = ICUType_2_measurements_training.count() 
ICUType_2_measurements_training
# Out:
# RecordID       75648
# level_1        75648
# Time           75648
# ALP              506
# ALT              521
# AST              520
# Age            73045
# Albumin          352
# BUN             4918
# Bilirubin        513
# Cholesterol       22
# Creatinine      4931
# DiasABP        59161
# FiO2           12765
# GCS            20097
# Gender          1576
# Glucose         3562
# HCO3            4573
# HCT             8246
# HR             69361
# Height         73045
# ICUType         1576
# K               4028
# Lactate         2629
# MAP            59288
# MechVent       12460
# Mg              4732
# NIDiasABP      16391
# NIMAP          16254
# NISysABP       16423
# Na              3836
# PaCO2          15195
# PaO2           15149
# Platelets       6072
# RespRate        3273
# SaO2            8202
# SysABP         59163
# Temp           44244
# TroponinI        107
# TroponinT        197
# Urine          63537
# WBC             5088
# Weight         39661
# pH             16665
# dtype: int64

# %%
training_ICUType_3 = train_X[train_X['ICUType'] == 3.0]
training_ICUType_3 = training_ICUType_3[training_ICUType_3["Time"] == 0.0]
training_ICUType_3_ids = training_ICUType_3["RecordID"]
ICUType_3_measurements_training = train_X[train_X["RecordID"].isin(training_ICUType_3_ids)]
ICUType_3_measurements_training = ICUType_3_measurements_training.count() 
ICUType_3_measurements_training
# Out:
# RecordID       133872
# level_1        133872
# Time           133872
# ALP              2828
# ALT              2918
# AST              2919
# Age            124347
# Albumin          2196
# BUN             10038
# Bilirubin        3051
# Cholesterol       132
# Creatinine      10081
# DiasABP         46736
# FiO2            19812
# GCS             35667
# Gender           2789
# Glucose          9993
# HCO3            10050
# HCT             11791
# HR             119741
# Height         124347
# ICUType          2789
# K               10865
# Lactate          5051
# MAP             46070
# MechVent        18176
# Mg               9471
# NIDiasABP       76941
# NIMAP           75526
# NISysABP        76969
# Na              10272
# PaCO2            9983
# PaO2             9991
# Platelets        9106
# RespRate        41465
# SaO2             1545
# SysABP          46741
# Temp            38334
# TroponinI         339
# TroponinT        1813
# Urine           81403
# WBC              8706
# Weight          87279
# pH              10134
# dtype: int64

# %%
training_ICUType_4 = train_X[train_X['ICUType'] == 4.0]
training_ICUType_4 = training_ICUType_4[training_ICUType_4["Time"] == 0.0]
training_ICUType_4_ids = training_ICUType_4["RecordID"]
ICUType_4_measurements_training = train_X[train_X["RecordID"].isin(training_ICUType_4_ids)]
ICUType_4_measurements_training = ICUType_4_measurements_training.count() 
ICUType_4_measurements_training
# Out:
# RecordID       106032
# level_1        106032
# Time           106032
# ALP              1808
# ALT              1838
# AST              1838
# Age            101280
# Albumin          1466
# BUN              7984
# Bilirubin        1803
# Cholesterol       144
# Creatinine       7997
# DiasABP         70950
# FiO2            19658
# GCS             49194
# Gender           2209
# Glucose          8043
# HCO3             7882
# HCT             10333
# HR              97361
# Height         101280
# ICUType          2209
# K                8780
# Lactate          6252
# MAP             70410
# MechVent        19515
# Mg               8193
# NIDiasABP       37298
# NIMAP           36802
# NISysABP        37340
# Na               8482
# PaCO2           12676
# PaO2            12647
# Platelets        8114
# RespRate        25508
# SaO2             2280
# SysABP          70955
# Temp            38413
# TroponinI         178
# TroponinT         873
# Urine           80399
# WBC              7565
# Weight          44390
# pH              12860
# dtype: int64

# %%
age_65_and_above_training = train_X[train_X["Age"] >= 65]
age_65_and_above_training = age_65_and_above_training[age_65_and_above_training ["Time"] == 0.0]
age_65_and_above_training_ids = age_65_and_above_training ["RecordID"]
age_65_and_above_measurements_training = train_X[train_X["RecordID"].isin(age_65_and_above_training_ids)]
age_65_and_above_measurements_training = age_65_and_above_measurements_training.count()
age_65_and_above_measurements_training
# Out:
# RecordID       203376
# level_1        203376
# Time           203376
# ALP              2654
# ALT              2715
# AST              2715
# Age            192154
# Albumin          2268
# BUN             14307
# Bilirubin        2780
# Cholesterol       375
# Creatinine      14393
# DiasABP        109830
# FiO2            31637
# GCS             63660
# Gender           4237
# Glucose         13309
# HCO3            13994
# HCT             19103
# HR             184426
# Height         192154
# ICUType          4237
# K               14965
# Lactate          7968
# MAP            109246
# MechVent        29659
# Mg              14082
# NIDiasABP       87423
# NIMAP           86395
# NISysABP        87489
# Na              13878
# PaCO2           23378
# PaO2            23341
# Platelets       14620
# RespRate        50470
# SaO2             9069
# SysABP         109838
# Temp            78448
# TroponinI         569
# TroponinT        2827
# Urine          143802
# WBC             13331
# Weight         109600
# pH              24457
# dtype: int64

# %%
# Motivação para o teste: A quantidade de valores no grupo de idade que estava na tabela, era muito maior do que a quantidade de 
# valores para o grupo de gênero, o que não fazia sentido, pois, já que não temos dados faltantes dessas variáveis em ambos os grupos
# se gênero tem n ocorrências, idade deve ter n ocorrências também, e vice-versa. 

# Descoberta: Através do teste, vimos que tinha casos em que o valor do campo idade, se repete durante a série temporal do paciente, e visto isso, nós ajustamos o código para pegar apenas a primeira ocorrência de valor para cada recordID.
# Também descobrimos que, como estamos filtrando apenas os gêneros female e male e há um campo para gênero indefinido, o grupo de Age estava pegando as idades desse campo de gênero indefinido também, o que estava fazendo com que 
# a soma total de ocorrências para o grupo de Age estivesse maior do que para o grupo de Gender.

# teste2 = train_X[train_X['Age'] >= 65]
# teste2["RecordID"].value_counts()

# %%
age_under_65_training  = train_X[train_X["Age"] < 65]
age_under_65_training  = age_under_65_training[age_under_65_training["Time"] == 0.0]
age_under_65_training_ids = age_under_65_training["RecordID"]
age_under_65_measurements_training = train_X[train_X["RecordID"].isin(age_under_65_training_ids)]
age_under_65_measurements_training  = age_under_65_measurements_training .count()
age_under_65_measurements_training
# Out:
# RecordID       164832
# level_1        164832
# Time           164832
# ALP              3275
# ALT              3391
# AST              3390
# Age            154699
# Albumin          2341
# BUN             12361
# Bilirubin        3409
# Cholesterol       266
# Creatinine      12415
# DiasABP         88486
# FiO2            26238
# GCS             54827
# Gender           3434
# Glucose         11861
# HCO3            12110
# HCT             15897
# HR             147836
# Height         154699
# ICUType          3434
# K               13074
# Lactate          7141
# MAP             87864
# MechVent        25732
# Mg              12028
# NIDiasABP       68733
# NIMAP           67606
# NISysABP        68787
# Na              12287
# PaCO2           18778
# PaO2            18747
# Platelets       12459
# RespRate        38430
# SaO2             5505
# SysABP          88491
# Temp            58330
# TroponinI         218
# TroponinT        1173
# Urine          111648
# WBC             11393
# Weight          85444
# pH              19606
# dtype: int64

# %%
filtered_train_X = train_X[(train_X['Height'] != -1) & (train_X['Weight'] != -1) & (train_X['Height'].notna()) & (train_X['Weight'].notna())]

# %%
def classify_BMI(BMI):
    if BMI <= 18.5:
        return "Baixo peso"
    elif BMI >= 18.6 and BMI <= 24.9:
        return "Peso normal"
    elif BMI >= 25 and BMI <= 29.9:
        return "Sobrepeso"
    elif BMI >= 30 and BMI <= 34.9:
        return "Obesidade grau 1"
    elif BMI >= 35 and BMI <= 39.9:
        return "Obesidade grau 2"
    elif BMI >= 40:
        return "Obesidade grau 3"

# %%
filtered_train_X_meters = filtered_train_X.copy()
filtered_train_X_meters['Height'] = filtered_train_X['Height'] / 100 # Converting Height from cm to meters
filtered_train_X_meters['Height']
# Out:
# 240       1.803
# 288       1.626
# 289       1.626
# 290       1.626
# 291       1.626
#           ...
# 575321    1.727
# 575322    1.727
# 575323    1.727
# 575325    1.727
# 575327    1.727
# Name: Height, Length: 101281, dtype: float64

# %%
bmi_data_train = filtered_train_X_meters
bmi_data_train["BMI"] = round(filtered_train_X_meters["Weight"] / (filtered_train_X_meters["Height"] ** 2), 1)
bmi_data_train["Classificacao"] = bmi_data_train["BMI"].apply(classify_BMI)
bmi_data_train.head()
# Out:
#      RecordID  level_1  Time  ALP  ALT  AST   Age  Albumin   BUN  Bilirubin  \
# 240    132547        0   0.0  NaN  NaN  NaN  64.0      NaN   NaN        NaN
# 288    132548        0   0.0  NaN  NaN  NaN  68.0      NaN   NaN        NaN
# 289    132548        1   1.0  NaN  NaN  NaN  68.0      NaN   NaN        NaN
# 290    132548        2   2.0  NaN  NaN  NaN  68.0      NaN  32.0        NaN
# 291    132548        3   3.0  NaN  NaN  NaN  68.0      NaN   NaN        NaN
#
#      ...      SysABP  Temp  TroponinI  TroponinT  Urine  WBC  Weight  pH  \
# 240  ...         NaN   NaN        NaN        NaN    NaN  NaN   114.0 NaN
# 288  ...         NaN  36.3        NaN        NaN    NaN  NaN    87.0 NaN
# 289  ...  205.000000  35.8        NaN        NaN  120.0  NaN    87.0 NaN
# 290  ...  212.142857   NaN        NaN        NaN   60.0  6.2    87.0 NaN
# 291  ...  201.250000   NaN        NaN        NaN  140.0  NaN    87.0 NaN
#
#       BMI     Classificacao
# 240  35.1  Obesidade grau 2
# 288  32.9  Obesidade grau 1
# 289  32.9  Obesidade grau 1
# 290  32.9  Obesidade grau 1
# 291  32.9  Obesidade grau 1
#
# [5 rows x 46 columns]

# %%
bmi_data_train = bmi_data_train.groupby("RecordID").first().reset_index()
bmi_data_train
# Out:
#       RecordID  level_1  Time   ALP   ALT    AST   Age  Albumin   BUN  \
# 0       132547        0   0.0   NaN   NaN    NaN  64.0      NaN   NaN
# 1       132548        0   0.0   NaN   NaN    NaN  68.0      NaN  32.0
# 2       132551        0   0.0  47.0  46.0   82.0  78.0      1.9  81.0
# 3       132555        0   0.0   NaN   NaN    NaN  74.0      NaN  19.0
# 4       132568        0   0.0   NaN   NaN    NaN  66.0      NaN  18.0
# ...        ...      ...   ...   ...   ...    ...   ...      ...   ...
# 3975    163013        0   0.0  82.0  11.0   30.0  74.0      2.5  30.0
# 3976    163016        0   0.0   NaN  27.0  120.0  65.0      NaN  29.0
# 3977    163021        0   0.0   NaN   NaN    NaN  72.0      NaN   9.0
# 3978    163029        0   0.0   NaN   NaN    NaN  61.0      NaN   NaN
# 3979    163034        0   0.0   NaN   NaN    NaN  60.0      NaN  15.0
#
#       Bilirubin  ...  SysABP  Temp  TroponinI  TroponinT  Urine   WBC  Weight  \
# 0           NaN  ...     NaN   NaN        NaN        NaN    NaN   NaN   114.0
# 1           NaN  ...  205.00  36.3        0.7        NaN  120.0   6.2    87.0
# 2           0.3  ...  102.75  38.0        3.5        NaN  120.0  16.1    48.4
# 3           NaN  ...   98.00  34.8        NaN        NaN   35.0   9.0    66.1
# 4           NaN  ...     NaN  36.1        NaN        NaN  220.0  14.8    84.5
# ...         ...  ...     ...   ...        ...        ...    ...   ...     ...
# 3975        1.2  ...  118.00  36.5        NaN       0.03   40.0   9.6    68.6
# 3976        0.4  ...  101.00  38.1        NaN        NaN   75.0   8.0    63.6
# 3977        NaN  ...     NaN   NaN        NaN        NaN    NaN   8.6    62.0
# 3978        NaN  ...     NaN   NaN        NaN        NaN    NaN   NaN    85.0
# 3979        NaN  ...  103.00  37.9        NaN        NaN  160.0   6.1    85.0
#
#         pH   BMI     Classificacao
# 0      NaN  35.1  Obesidade grau 2
# 1      NaN  32.9  Obesidade grau 1
# 2     7.40  18.3        Baixo peso
# 3     7.39  21.5       Peso normal
# 4      NaN  34.1  Obesidade grau 1
# ...    ...   ...               ...
# 3975  7.35  29.5         Sobrepeso
# 3976  7.37  24.8       Peso normal
# 3977   NaN  20.8       Peso normal
# 3978   NaN  28.5         Sobrepeso
# 3979  7.43  28.5         Sobrepeso
#
# [3980 rows x 46 columns]

# %%
bmi_data_train["Classificacao"].value_counts()
# Out:
# Classificacao
# Sobrepeso           1389
# Peso normal         1179
# Obesidade grau 1     701
# Obesidade grau 2     306
# Obesidade grau 3     286
# Baixo peso           119
# Name: count, dtype: int64

# %%
classification_undefined_training_ids = bmi_data_train["RecordID"]
classification_undefined_measurements_training = train_X[~train_X["RecordID"].isin(classification_undefined_training_ids)]
classification_undefined_measurements_training = classification_undefined_measurements_training.count()
classification_undefined_measurements_training
# Out:
# RecordID       177168
# level_1        177168
# Time           177168
# ALP              2842
# ALT              2936
# AST              2940
# Age            163635
# Albumin          2338
# BUN             12435
# Bilirubin        2999
# Cholesterol       291
# Creatinine      12507
# DiasABP         70002
# FiO2            24464
# GCS             59273
# Gender           3691
# Glucose         12409
# HCO3            12349
# HCT             15066
# HR             157307
# Height         163635
# ICUType          3691
# K               13664
# Lactate          5897
# MAP             69222
# MechVent        22601
# Mg              12087
# NIDiasABP       95165
# NIMAP           93628
# NISysABP        95226
# Na              12891
# PaCO2           12415
# PaO2            12393
# Platelets       11551
# RespRate        60443
# SaO2             1963
# SysABP          70010
# Temp            47528
# TroponinI         309
# TroponinT        2195
# Urine          112916
# WBC             11028
# Weight          93763
# pH              12632
# dtype: int64

# %%
classification_low_weight_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Baixo peso']
classification_low_weight_training_ids = classification_low_weight_training["RecordID"]
classification_measurements_l_w_t = train_X[train_X["RecordID"].isin(classification_low_weight_training_ids)]
classification_measurements_l_w_t = classification_measurements_l_w_t.count() 
classification_measurements_l_w_t
# Out:
# RecordID       5712
# level_1        5712
# Time           5712
# ALP              82
# ALT              84
# AST              85
# Age            5499
# Albumin          74
# BUN             410
# Bilirubin        87
# Cholesterol      11
# Creatinine      411
# DiasABP        3672
# FiO2            923
# GCS            1733
# Gender          119
# Glucose         389
# HCO3            406
# HCT             555
# HR             5303
# Height         5499
# ICUType         119
# K               435
# Lactate         303
# MAP            3712
# MechVent        975
# Mg              423
# NIDiasABP      2048
# NIMAP          1993
# NISysABP       2048
# Na              404
# PaCO2           768
# PaO2            774
# Platelets       431
# RespRate       1016
# SaO2            309
# SysABP         3673
# Temp           2433
# TroponinI        25
# TroponinT        51
# Urine          4093
# WBC             384
# Weight         2919
# pH              812
# dtype: int64

# %%
classification_normal_weight_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Peso normal']
classification_normal_weight_training_ids = classification_normal_weight_training["RecordID"]
classification_measurements_n_w_t = train_X[train_X["RecordID"].isin(classification_normal_weight_training_ids)]
classification_measurements_n_w_t = classification_measurements_n_w_t.count() 
classification_measurements_n_w_t
# Out:
# RecordID       56592
# level_1        56592
# Time           56592
# ALP              898
# ALT              926
# AST              924
# Age            54320
# Albumin          691
# BUN             4199
# Bilirubin        927
# Cholesterol       96
# Creatinine      4217
# DiasABP        37157
# FiO2            9560
# GCS            18365
# Gender          1179
# Glucose         3829
# HCO3            4059
# HCT             5802
# HR             51911
# Height         54320
# ICUType         1179
# K               4349
# Lactate         2752
# MAP            37004
# MechVent        9453
# Mg              4170
# NIDiasABP      19104
# NIMAP          18963
# NISysABP       19120
# Na              4004
# PaCO2           8274
# PaO2            8246
# Platelets       4547
# RespRate        8700
# SaO2            3344
# SysABP         37158
# Temp           25556
# TroponinI        140
# TroponinT        526
# Urine          41479
# WBC             4032
# Weight         28986
# pH              8755
# dtype: int64

# %%
classification_overweight_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Sobrepeso']
classification_overweight_training_ids = classification_overweight_training['RecordID']
classification_measurements_o_w_t = train_X[train_X["RecordID"].isin(classification_overweight_training_ids)]
classification_measurements_o_w_t = classification_measurements_o_w_t.count() 
classification_measurements_o_w_t
# Out:
# RecordID       66672
# level_1        66672
# Time           66672
# ALP             1076
# ALT             1110
# AST             1108
# Age            63924
# Albumin          768
# BUN             5001
# Bilirubin       1117
# Cholesterol      133
# Creatinine      5030
# DiasABP        45440
# FiO2           11376
# GCS            20532
# Gender          1389
# Glucose         4421
# HCO3            4815
# HCT             7177
# HR             60849
# Height         63924
# ICUType         1389
# K               4959
# Lactate         3059
# MAP            45341
# MechVent       11165
# Mg              4935
# NIDiasABP      20998
# NIMAP          20785
# NISysABP       21020
# Na              4582
# PaCO2          10572
# PaO2           10547
# Platelets       5593
# RespRate        9826
# SaO2            4689
# SysABP         45443
# Temp           32002
# TroponinI        164
# TroponinT        618
# Urine          49803
# WBC             4871
# Weight         34793
# pH             11243
# dtype: int64

# %%
classification_obesity_grade1_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Obesidade grau 1']
classification_obesity_grade1_training_ids = classification_obesity_grade1_training["RecordID"]
classification_measurements_ob1_t = train_X[train_X["RecordID"].isin(classification_obesity_grade1_training_ids)]
classification_measurements_ob1_t  = classification_measurements_ob1_t .count() 
classification_measurements_ob1_t
# Out:
# RecordID       33648
# level_1        33648
# Time           33648
# ALP              569
# ALT              581
# AST              581
# Age            32321
# Albumin          405
# BUN             2509
# Bilirubin        585
# Cholesterol       56
# Creatinine      2519
# DiasABP        23185
# FiO2            6093
# GCS            10234
# Gender           701
# Glucose         2252
# HCO3            2427
# HCT             3547
# HR             30908
# Height         32321
# ICUType          701
# K               2542
# Lactate         1648
# MAP            23003
# MechVent        5965
# Mg              2444
# NIDiasABP      10216
# NIMAP          10112
# NISysABP       10229
# Na              2346
# PaCO2           5431
# PaO2            5429
# Platelets       2719
# RespRate        4569
# SaO2            2248
# SysABP         23185
# Temp           16244
# TroponinI        104
# TroponinT        335
# Urine          25962
# WBC             2391
# Weight         18076
# pH              5735
# dtype: int64

# %%
classification_obesity_grade2_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Obesidade grau 2']
classification_obesity_grade2_training_ids = classification_obesity_grade2_training["RecordID"]
classification_measurements_ob2_t = train_X[train_X["RecordID"].isin(classification_obesity_grade2_training_ids)]
classification_measurements_ob2_t = classification_measurements_ob2_t.count() 
classification_measurements_ob2_t
# Out:
# RecordID       14688
# level_1        14688
# Time           14688
# ALP              237
# ALT              238
# AST              237
# Age            14003
# Albumin          169
# BUN             1113
# Bilirubin        243
# Cholesterol       30
# Creatinine      1123
# DiasABP         9937
# FiO2            2613
# GCS             4408
# Gender           306
# Glucose          975
# HCO3            1080
# HCT             1537
# HR             13388
# Height         14003
# ICUType          306
# K               1082
# Lactate          711
# MAP             9939
# MechVent        2488
# Mg              1055
# NIDiasABP       4355
# NIMAP           4299
# NISysABP        4357
# Na              1020
# PaCO2           2382
# PaO2            2381
# Platelets       1222
# RespRate        2626
# SaO2            1056
# SysABP          9937
# Temp            6948
# TroponinI         22
# TroponinT        153
# Urine          10925
# WBC             1097
# Weight          8623
# pH              2480
# dtype: int64

# %%
classification_obesity_grade3_training = bmi_data_train[bmi_data_train["Classificacao"] == 'Obesidade grau 3']
classification_obesity_grade3_training_ids = classification_obesity_grade3_training["RecordID"]
classification_measurements_ob3_t = train_X[train_X["RecordID"].isin(classification_obesity_grade3_training_ids)]
classification_measurements_ob3_t = classification_measurements_ob3_t.count() 
classification_measurements_ob3_t
# Out:
# RecordID       13728
# level_1        13728
# Time           13728
# ALP              225
# ALT              231
# AST              230
# Age            13151
# Albumin          164
# BUN             1001
# Bilirubin        231
# Cholesterol       24
# Creatinine      1001
# DiasABP         8923
# FiO2            2846
# GCS             3942
# Gender           286
# Glucose          895
# HCO3             968
# HCT             1316
# HR             12596
# Height         13151
# ICUType          286
# K               1008
# Lactate          739
# MAP             8889
# MechVent        2744
# Mg               996
# NIDiasABP       4270
# NIMAP           4221
# NISysABP        4276
# Na               918
# PaCO2           2314
# PaO2            2318
# Platelets       1016
# RespRate        1720
# SaO2             965
# SysABP          8923
# Temp            6067
# TroponinI         23
# TroponinT        122
# Urine          10272
# WBC              921
# Weight          7884
# pH              2406
# dtype: int64

# %%
df_columns = train_X.columns
df_columns
# Out:
# Index(['RecordID', 'level_1', 'Time', 'ALP', 'ALT', 'AST', 'Age', 'Albumin',
#        'BUN', 'Bilirubin', 'Cholesterol', 'Creatinine', 'DiasABP', 'FiO2',
#        'GCS', 'Gender', 'Glucose', 'HCO3', 'HCT', 'HR', 'Height', 'ICUType',
#        'K', 'Lactate', 'MAP', 'MechVent', 'Mg', 'NIDiasABP', 'NIMAP',
#        'NISysABP', 'Na', 'PaCO2', 'PaO2', 'Platelets', 'RespRate', 'SaO2',
#        'SysABP', 'Temp', 'TroponinI', 'TroponinT', 'Urine', 'WBC', 'Weight',
#        'pH'],
#       dtype='object')

# %%
df_train = pd.DataFrame(columns=df_columns)
df_train_transpose = df_train.T
df_train_transpose["Female"] = female_gender_measurements_training
df_train_transpose["Male"] = male_gender_measurements_training
df_train_transpose["Undefined Gender"] = undefined_gender_measurements_training
df_train_transpose["ICUType 1"] = ICUType_1_measurements_training 
df_train_transpose["ICUType 2"] = ICUType_2_measurements_training 
df_train_transpose["ICUType 3"] = ICUType_3_measurements_training 
df_train_transpose["ICUType 4"] = ICUType_4_measurements_training 
df_train_transpose["Age 65+"] = age_65_and_above_measurements_training
df_train_transpose["Age 65-"] = age_under_65_measurements_training 
df_train_transpose['Undefined Classification'] = classification_undefined_measurements_training
df_train_transpose['Low Weight'] = classification_measurements_l_w_t 
df_train_transpose['Normal Weight'] = classification_measurements_n_w_t 
df_train_transpose['Overweight'] = classification_measurements_o_w_t 
df_train_transpose['Obesity Grade 1'] = classification_measurements_ob1_t 
df_train_transpose['Obesity Grade 2'] = classification_measurements_ob2_t 
df_train_transpose['Obesity Grade 3'] = classification_measurements_ob3_t 
df_train_transpose = df_train_transpose.drop('RecordID',axis=0)
df_train_transpose = df_train_transpose.drop('level_1',axis=0)
df_train_transpose = df_train_transpose.drop('Time',axis=0)
df_train_transpose = df_train_transpose.drop('Age',axis=0)
df_train_transpose = df_train_transpose.drop('Gender',axis=0)
df_train_transpose = df_train_transpose.drop('Height',axis=0)
df_train_transpose = df_train_transpose.drop('ICUType',axis=0)

#df_test_transpose.style.set_caption("Repeated Measurements per variable by demographics")

display(HTML("<h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Train Set</h2>"))
df_train_transpose
# Out:
# <h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Train Set</h2>
#              Female    Male  Undefined Gender  ICUType 1  ICUType 2  \
# ALP            2565    3361                 3        787        506
# ALT            2646    3456                 4        829        521
# AST            2641    3460                 4        828        520
# Albumin        2061    2546                 2        595        352
# BUN           11780   14864                24       3728       4918
# Bilirubin      2687    3499                 3        822        513
# Cholesterol     270     371                 0        343         22
# Creatinine    11829   14955                24       3799       4931
# DiasABP       83387  114687               242      21469      59161
# FiO2          25129   32714                32       5640      12765
# GCS           53030   65350               107      13529      20097
# Glucose       11214   13932                24       3572       3562
# HCO3          11573   14507                24       3599       4573
# HCT           14996   19981                23       4630       8246
# HR           148057  183886               319      45799      69361
# K             12443   15571                25       4366       4028
# Lactate        6358    8748                 3       1177       2629
# MAP           82890  113984               236      21342      59288
# MechVent      24446   30917                28       5240      12460
# Mg            11536   14551                23       3714       4732
# NIDiasABP     72980   83038               138      25526      16391
# NIMAP         71854   82009               138      25419      16254
# NISysABP      73033   83105               138      25544      16423
# Na            11662   14480                23       3575       3836
# PaCO2         17290   24841                25       4302      15195
# PaO2          17266   24797                25       4301      15149
# Platelets     11616   15441                22       3787       6072
# RespRate      43867   44898               135      18654       3273
# SaO2           6069    8504                 1       2547       8202
# SysABP        83393  114694               242      21470      59163
# Temp          58295   78366               117      15787      44244
# TroponinI       379     407                 1        163        107
# TroponinT      1744    2249                 7       1117        197
# Urine        113878  141347               225      30111      63537
# WBC           10811   13891                22       3365       5088
# Weight        87627  107207               210      23714      39661
# pH            17932   26101                30       4404      16665
#
#              ICUType 3  ICUType 4  Age 65+  Age 65-  Undefined Classification  \
# ALP               2828       1808     2654     3275                      2842
# ALT               2918       1838     2715     3391                      2936
# AST               2919       1838     2715     3390                      2940
# Albumin           2196       1466     2268     2341                      2338
# BUN              10038       7984    14307    12361                     12435
# Bilirubin         3051       1803     2780     3409                      2999
# Cholesterol        132        144      375      266                       291
# Creatinine       10081       7997    14393    12415                     12507
# DiasABP          46736      70950   109830    88486                     70002
# FiO2             19812      19658    31637    26238                     24464
# GCS              35667      49194    63660    54827                     59273
# Glucose           9993       8043    13309    11861                     12409
# HCO3             10050       7882    13994    12110                     12349
# HCT              11791      10333    19103    15897                     15066
# HR              119741      97361   184426   147836                    157307
# K                10865       8780    14965    13074                     13664
# Lactate           5051       6252     7968     7141                      5897
# MAP              46070      70410   109246    87864                     69222
# MechVent         18176      19515    29659    25732                     22601
# Mg                9471       8193    14082    12028                     12087
# NIDiasABP        76941      37298    87423    68733                     95165
# NIMAP            75526      36802    86395    67606                     93628
# NISysABP         76969      37340    87489    68787                     95226
# Na               10272       8482    13878    12287                     12891
# PaCO2             9983      12676    23378    18778                     12415
# PaO2              9991      12647    23341    18747                     12393
# Platelets         9106       8114    14620    12459                     11551
# RespRate         41465      25508    50470    38430                     60443
# SaO2              1545       2280     9069     5505                      1963
# SysABP           46741      70955   109838    88491                     70010
# Temp             38334      38413    78448    58330                     47528
# TroponinI          339        178      569      218                       309
# TroponinT         1813        873     2827     1173                      2195
# Urine            81403      80399   143802   111648                    112916
# WBC               8706       7565    13331    11393                     11028
# Weight           87279      44390   109600    85444                     93763
# pH               10134      12860    24457    19606                     12632
#
#              Low Weight  Normal Weight  Overweight  Obesity Grade 1  \
# ALP                  82            898        1076              569
# ALT                  84            926        1110              581
# AST                  85            924        1108              581
# Albumin              74            691         768              405
# BUN                 410           4199        5001             2509
# Bilirubin            87            927        1117              585
# Cholesterol          11             96         133               56
# Creatinine          411           4217        5030             2519
# DiasABP            3672          37157       45440            23185
# FiO2                923           9560       11376             6093
# GCS                1733          18365       20532            10234
# Glucose             389           3829        4421             2252
# HCO3                406           4059        4815             2427
# HCT                 555           5802        7177             3547
# HR                 5303          51911       60849            30908
# K                   435           4349        4959             2542
# Lactate             303           2752        3059             1648
# MAP                3712          37004       45341            23003
# MechVent            975           9453       11165             5965
# Mg                  423           4170        4935             2444
# NIDiasABP          2048          19104       20998            10216
# NIMAP              1993          18963       20785            10112
# NISysABP           2048          19120       21020            10229
# Na                  404           4004        4582             2346
# PaCO2               768           8274       10572             5431
# PaO2                774           8246       10547             5429
# Platelets           431           4547        5593             2719
# RespRate           1016           8700        9826             4569
# SaO2                309           3344        4689             2248
# SysABP             3673          37158       45443            23185
# Temp               2433          25556       32002            16244
# TroponinI            25            140         164              104
# TroponinT            51            526         618              335
# Urine              4093          41479       49803            25962
# WBC                 384           4032        4871             2391
# Weight             2919          28986       34793            18076
# pH                  812           8755       11243             5735
#
#              Obesity Grade 2  Obesity Grade 3
# ALP                      237              225
# ALT                      238              231
# AST                      237              230
# Albumin                  169              164
# BUN                     1113             1001
# Bilirubin                243              231
# Cholesterol               30               24
# Creatinine              1123             1001
# DiasABP                 9937             8923
# FiO2                    2613             2846
# GCS                     4408             3942
# Glucose                  975              895
# HCO3                    1080              968
# HCT                     1537             1316
# HR                     13388            12596
# K                       1082             1008
# Lactate                  711              739
# MAP                     9939             8889
# MechVent                2488             2744
# Mg                      1055              996
# NIDiasABP               4355             4270
# NIMAP                   4299             4221
# NISysABP                4357             4276
# Na                      1020              918
# PaCO2                   2382             2314
# PaO2                    2381             2318
# Platelets               1222             1016
# RespRate                2626             1720
# SaO2                    1056              965
# SysABP                  9937             8923
# Temp                    6948             6067
# TroponinI                 22               23
# TroponinT                153              122
# Urine                  10925            10272
# WBC                     1097              921
# Weight                  8623             7884
# pH                      2480             2406

# %% [markdown]
# <h3>Validation data</h3>

# %% [markdown]
# <h4>Loading validation dataset</h4>

# %%
validation_X = physionet2012_dataset['val_X']

# %%
validation_female_gender = validation_X[validation_X['Gender'] == 0.0]
validation_female_gender_ids = validation_female_gender["RecordID"]
female_gender_measurements_validation = validation_X[validation_X["RecordID"].isin(validation_female_gender_ids)]
female_gender_measurements_validation = female_gender_measurements_validation.count()
female_gender_measurements_validation
# Out:
# RecordID       39408
# level_1        39408
# Time           39408
# ALP              698
# ALT              710
# AST              712
# Age            37118
# Albumin          498
# BUN             2862
# Bilirubin        715
# Cholesterol       66
# Creatinine      2875
# DiasABP        20889
# FiO2            6244
# GCS            12708
# Gender           821
# Glucose         2730
# HCO3            2830
# HCT             3654
# HR             35658
# Height         37118
# ICUType          821
# K               3013
# Lactate         1581
# MAP            20765
# MechVent        6148
# Mg              2834
# NIDiasABP      16945
# NIMAP          16730
# NISysABP       16961
# Na              2879
# PaCO2           4326
# PaO2            4324
# Platelets       2833
# RespRate        9728
# SaO2            1481
# SysABP         20890
# Temp           13912
# TroponinI         63
# TroponinT        433
# Urine          27531
# WBC             2628
# Weight         21836
# pH              4475
# dtype: int64

# %%
validation_male_gender = validation_X[validation_X['Gender'] == 1.0]
validation_male_gender_ids = validation_male_gender["RecordID"]
male_gender_measurements_validation = validation_X[validation_X["RecordID"].isin(validation_male_gender_ids)]
male_gender_measurements_validation = male_gender_measurements_validation.count()
male_gender_measurements_validation
# Out:
# RecordID       52656
# level_1        52656
# Time           52656
# ALP              854
# ALT              880
# AST              885
# Age            49473
# Albumin          630
# BUN             3775
# Bilirubin        875
# Cholesterol       96
# Creatinine      3785
# DiasABP        29059
# FiO2            8099
# GCS            16859
# Gender          1097
# Glucose         3447
# HCO3            3664
# HCT             5072
# HR             47294
# Height         49473
# ICUType         1097
# K               3852
# Lactate         2150
# MAP            28898
# MechVent        7816
# Mg              3729
# NIDiasABP      21654
# NIMAP          21383
# NISysABP       21677
# Na              3643
# PaCO2           6369
# PaO2            6362
# Platelets       3926
# RespRate       11226
# SaO2            2267
# SysABP         29060
# Temp           20242
# TroponinI         97
# TroponinT        563
# Urine          36053
# WBC             3519
# Weight         27453
# pH              6755
# dtype: int64

# %%
validation_undefined_gender = validation_X[validation_X['Gender'] == -1.0]
validation_undefined_gender_ids = validation_undefined_gender["RecordID"]
undefined_gender_measurements_validation = validation_X[validation_X["RecordID"].isin(validation_undefined_gender_ids)]
undefined_gender_measurements_validation = undefined_gender_measurements_validation.count()
undefined_gender_measurements_validation
# Out:
# RecordID       0
# level_1        0
# Time           0
# ALP            0
# ALT            0
# AST            0
# Age            0
# Albumin        0
# BUN            0
# Bilirubin      0
# Cholesterol    0
# Creatinine     0
# DiasABP        0
# FiO2           0
# GCS            0
# Gender         0
# Glucose        0
# HCO3           0
# HCT            0
# HR             0
# Height         0
# ICUType        0
# K              0
# Lactate        0
# MAP            0
# MechVent       0
# Mg             0
# NIDiasABP      0
# NIMAP          0
# NISysABP       0
# Na             0
# PaCO2          0
# PaO2           0
# Platelets      0
# RespRate       0
# SaO2           0
# SysABP         0
# Temp           0
# TroponinI      0
# TroponinT      0
# Urine          0
# WBC            0
# Weight         0
# pH             0
# dtype: int64

# %%
validation_ICUType_1 = validation_X[validation_X['ICUType'] == 1.0]
validation_ICUType_1 = validation_ICUType_1[validation_ICUType_1['Time'] == 0.0]
validation_ICUType_1_ids = validation_ICUType_1['RecordID']
ICUType_1_measurements_validation = validation_X[validation_X['RecordID'].isin(validation_ICUType_1_ids)]
ICUType_1_measurements_validation = ICUType_1_measurements_validation.count()
ICUType_1_measurements_validation
# Out:
# RecordID       14160
# level_1        14160
# Time           14160
# ALP              208
# ALT              224
# AST              223
# Age            12959
# Albumin          168
# BUN             1027
# Bilirubin        215
# Cholesterol       83
# Creatinine      1041
# DiasABP         6039
# FiO2            1613
# GCS             3643
# Gender           295
# Glucose          964
# HCO3             989
# HCT             1249
# HR             12336
# Height         12959
# ICUType          295
# K               1174
# Lactate          353
# MAP             6022
# MechVent        1562
# Mg              1019
# NIDiasABP       6644
# NIMAP           6577
# NISysABP        6648
# Na               986
# PaCO2           1210
# PaO2            1212
# Platelets       1014
# RespRate        4373
# SaO2             687
# SysABP          6040
# Temp            4372
# TroponinI         50
# TroponinT        304
# Urine           7778
# WBC              914
# Weight          6617
# pH              1227
# dtype: int64

# %%
validation_ICUType_2 = validation_X[validation_X['ICUType'] == 2.0]
validation_ICUType_2 = validation_ICUType_2[validation_ICUType_2['Time'] == 0.0]
validation_ICUType_2_ids = validation_ICUType_2['RecordID']
ICUType_2_measurements_validation = validation_X[validation_X['RecordID'].isin(validation_ICUType_2_ids)]
ICUType_2_measurements_validation = ICUType_2_measurements_validation.count()
ICUType_2_measurements_validation
# Out:
# RecordID       20592
# level_1        20592
# Time           20592
# ALP              151
# ALT              157
# AST              158
# Age            19959
# Albumin           82
# BUN             1352
# Bilirubin        151
# Cholesterol        6
# Creatinine      1357
# DiasABP        16271
# FiO2            3459
# GCS             5363
# Gender           429
# Glucose          948
# HCO3            1253
# HCT             2316
# HR             18937
# Height         19959
# ICUType          429
# K               1088
# Lactate          754
# MAP            16308
# MechVent        3347
# Mg              1356
# NIDiasABP       4634
# NIMAP           4589
# NISysABP        4642
# Na              1058
# PaCO2           4242
# PaO2            4233
# Platelets       1733
# RespRate         725
# SaO2            2222
# SysABP         16271
# Temp           11793
# TroponinI         20
# TroponinT         58
# Urine          17521
# WBC             1405
# Weight         10782
# pH              4684
# dtype: int64

# %%
validation_ICUType_3 = validation_X[validation_X['ICUType'] == 3.0]
validation_ICUType_3 = validation_ICUType_3[validation_ICUType_3['Time'] == 0.0]
validation_ICUType_3_ids = validation_ICUType_3['RecordID']
ICUType_3_measurements_validation = validation_X[validation_X['RecordID'].isin(validation_ICUType_3_ids)]
ICUType_3_measurements_validation = ICUType_3_measurements_validation.count()
ICUType_3_measurements_validation
# Out:
# RecordID       31344
# level_1        31344
# Time           31344
# ALP              734
# ALT              747
# AST              747
# Age            28992
# Albumin          532
# BUN             2387
# Bilirubin        767
# Cholesterol       35
# Creatinine      2393
# DiasABP        11189
# FiO2            4621
# GCS             8277
# Gender           653
# Glucose         2383
# HCO3            2398
# HCT             2787
# HR             27924
# Height         28992
# ICUType          653
# K               2574
# Lactate         1311
# MAP            11031
# MechVent        4437
# Mg              2266
# NIDiasABP      17514
# NIMAP          17236
# NISysABP       17529
# Na              2456
# PaCO2           2501
# PaO2            2504
# Platelets       2155
# RespRate        9328
# SaO2             386
# SysABP         11190
# Temp            8961
# TroponinI         58
# TroponinT        441
# Urine          19017
# WBC             2071
# Weight         20468
# pH              2542
# dtype: int64

# %%
validation_ICUType_4 = validation_X[validation_X['ICUType'] == 4.0]
validation_ICUType_4 = validation_ICUType_4[validation_ICUType_4['Time'] == 0.0]
validation_ICUType_4_ids = validation_ICUType_4['RecordID']
ICUType_4_measurements_validation = validation_X[validation_X['RecordID'].isin(validation_ICUType_4_ids)]
ICUType_4_measurements_validation = ICUType_4_measurements_validation.count()
ICUType_4_measurements_validation
# Out:
# RecordID       25968
# level_1        25968
# Time           25968
# ALP              459
# ALT              462
# AST              469
# Age            24681
# Albumin          346
# BUN             1871
# Bilirubin        457
# Cholesterol       38
# Creatinine      1869
# DiasABP        16449
# FiO2            4650
# GCS            12284
# Gender           541
# Glucose         1882
# HCO3            1854
# HCT             2374
# HR             23755
# Height         24681
# ICUType          541
# K               2029
# Lactate         1313
# MAP            16302
# MechVent        4618
# Mg              1922
# NIDiasABP       9807
# NIMAP           9711
# NISysABP        9819
# Na              2022
# PaCO2           2742
# PaO2            2737
# Platelets       1857
# RespRate        6528
# SaO2             453
# SysABP         16449
# Temp            9028
# TroponinI         32
# TroponinT        193
# Urine          19268
# WBC             1757
# Weight         11422
# pH              2777
# dtype: int64

# %%
age_65_and_above_validation = validation_X[validation_X['Age'] >= 65]
age_65_and_above_validation = age_65_and_above_validation[age_65_and_above_validation['Time'] == 0.0]
age_65_and_above_validation_ids = age_65_and_above_validation['RecordID']
age_65_and_above_measurements_validation = validation_X[validation_X['RecordID'].isin(age_65_and_above_validation_ids)]
age_65_and_above_measurements_validation = age_65_and_above_measurements_validation.count()
age_65_and_above_measurements_validation
# Out:
# RecordID       49488
# level_1        49488
# Time           49488
# ALP              678
# ALT              691
# AST              696
# Age            46779
# Albumin          510
# BUN             3491
# Bilirubin        694
# Cholesterol       93
# Creatinine      3499
# DiasABP        27387
# FiO2            7866
# GCS            15262
# Gender          1031
# Glucose         3200
# HCO3            3394
# HCT             4714
# HR             44929
# Height         46779
# ICUType         1031
# K               3578
# Lactate         1824
# MAP            27251
# MechVent        7380
# Mg              3474
# NIDiasABP      20732
# NIMAP          20477
# NISysABP       20751
# Na              3364
# PaCO2           5775
# PaO2            5767
# Platelets       3549
# RespRate       11438
# SaO2            2272
# SysABP         27389
# Temp           18924
# TroponinI         99
# TroponinT        686
# Urine          34870
# WBC             3222
# Weight         27104
# pH              6088
# dtype: int64

# %%
age_under_65_validation = validation_X[validation_X['Age'] < 65]
age_under_65_validation = age_under_65_validation[age_under_65_validation['Time'] == 0.0]
age_under_65_validation_ids = age_under_65_validation["RecordID"]
age_under_65__measurements_validation = validation_X[validation_X["RecordID"].isin(age_under_65_validation_ids)]
age_under_65__measurements_validation = age_under_65__measurements_validation.count()
age_under_65__measurements_validation
# Out:
# RecordID       42576
# level_1        42576
# Time           42576
# ALP              874
# ALT              899
# AST              901
# Age            39812
# Albumin          618
# BUN             3146
# Bilirubin        896
# Cholesterol       69
# Creatinine      3161
# DiasABP        22561
# FiO2            6477
# GCS            14305
# Gender           887
# Glucose         2977
# HCO3            3100
# HCT             4012
# HR             38023
# Height         39812
# ICUType          887
# K               3287
# Lactate         1907
# MAP            22412
# MechVent        6584
# Mg              3089
# NIDiasABP      17867
# NIMAP          17636
# NISysABP       17887
# Na              3158
# PaCO2           4920
# PaO2            4919
# Platelets       3210
# RespRate        9516
# SaO2            1476
# SysABP         22561
# Temp           15230
# TroponinI         61
# TroponinT        310
# Urine          28714
# WBC             2925
# Weight         22185
# pH              5142
# dtype: int64

# %%
filtered_validation_X = validation_X[(validation_X['Height'] != -1) & (validation_X['Weight'] != -1) & (validation_X['Height'].notna()) & (validation_X['Weight'].notna())]

# %%
filtered_validation_X_meters = filtered_validation_X.copy()
filtered_validation_X_meters['Height'] = filtered_validation_X['Height'] / 100 # Converting Height from cm to meters
filtered_validation_X_meters['Height']
# Out:
# 48        1.753
# 67        1.753
# 68        1.753
# 69        1.753
# 70        1.753
#           ...
# 573549    1.727
# 573550    1.727
# 573551    1.727
# 574176    1.499
# 574560    1.689
# Name: Height, Length: 26100, dtype: float64

# %%
bmi_data_validation = filtered_validation_X_meters
bmi_data_validation["BMI"] = round(filtered_validation_X_meters["Weight"] / (filtered_validation_X_meters["Height"] ** 2), 1)
bmi_data_validation["Classificacao"] = bmi_data_validation["BMI"].apply(classify_BMI)
bmi_data_validation.head()
# Out:
#     RecordID  level_1  Time  ALP  ALT  AST   Age  Albumin  BUN  Bilirubin  \
# 48    132540        0   0.0  NaN  NaN  NaN  76.0      NaN  NaN        NaN
# 67    132540       19  19.0  NaN  NaN  NaN  76.0      NaN  NaN        NaN
# 68    132540       20  20.0  NaN  NaN  NaN  76.0      NaN  NaN        NaN
# 69    132540       21  21.0  NaN  NaN  NaN  76.0      NaN  NaN        NaN
# 70    132540       22  22.0  NaN  NaN  NaN  76.0      NaN  NaN        NaN
#
#     ...  SysABP  Temp  TroponinI  TroponinT  Urine  WBC  Weight    pH   BMI  \
# 48  ...     NaN   NaN        NaN        NaN    NaN  NaN    76.0  7.45  24.7
# 67  ...   122.0  37.5        NaN        NaN   50.0  NaN    80.6   NaN  26.2
# 68  ...   107.0  37.4        NaN        NaN  380.0  NaN    80.6   NaN  26.2
# 69  ...   121.0  37.5        NaN        NaN  170.0  NaN    80.6   NaN  26.2
# 70  ...   128.0  37.5        NaN        NaN  130.0  NaN    80.6   NaN  26.2
#
#     Classificacao
# 48    Peso normal
# 67      Sobrepeso
# 68      Sobrepeso
# 69      Sobrepeso
# 70      Sobrepeso
#
# [5 rows x 46 columns]

# %%
classification_undefined_validation_ids = bmi_data_validation["RecordID"]
classification_undefined_measurements_validation = validation_X[~validation_X["RecordID"].isin(classification_undefined_validation_ids)]
classification_undefined_measurements_validation = classification_undefined_measurements_validation.count()
classification_undefined_measurements_validation
# Out:
# RecordID       43248
# level_1        43248
# Time           43248
# ALP              766
# ALT              795
# AST              797
# Age            39829
# Albumin          596
# BUN             3049
# Bilirubin        788
# Cholesterol       78
# Creatinine      3065
# DiasABP        17056
# FiO2            6016
# GCS            14505
# Gender           901
# Glucose         3033
# HCO3            3027
# HCT             3652
# HR             38266
# Height         39829
# ICUType          901
# K               3332
# Lactate         1440
# MAP            16818
# MechVent        5577
# Mg              2980
# NIDiasABP      22961
# NIMAP          22686
# NISysABP       22980
# Na              3188
# PaCO2           2963
# PaO2            2959
# Platelets       2804
# RespRate       14454
# SaO2             512
# SysABP         17057
# Temp           11702
# TroponinI         62
# TroponinT        509
# Urine          27375
# WBC             2696
# Weight         23189
# pH              3021
# dtype: int64

# %%
classification_low_weight_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Baixo peso']
classification_low_weight_validation_ids = classification_low_weight_validation["RecordID"]
classification_measurements_l_w_v = validation_X[validation_X["RecordID"].isin(classification_low_weight_validation_ids)]
classification_measurements_l_w_v = classification_measurements_l_w_v.count() 
classification_measurements_l_w_v
# Out:
# RecordID       1632
# level_1        1632
# Time           1632
# ALP              22
# ALT              21
# AST              21
# Age            1584
# Albumin          17
# BUN             122
# Bilirubin        21
# Cholesterol       2
# Creatinine      122
# DiasABP         992
# FiO2            259
# GCS             537
# Gender           34
# Glucose         106
# HCO3            119
# HCT             156
# HR             1518
# Height         1584
# ICUType          34
# K               119
# Lactate          87
# MAP             992
# MechVent        294
# Mg              112
# NIDiasABP       588
# NIMAP           583
# NISysABP        588
# Na              118
# PaCO2           221
# PaO2            222
# Platelets       123
# RespRate        227
# SaO2            107
# SysABP          992
# Temp            716
# TroponinI         2
# TroponinT        20
# Urine          1234
# WBC             113
# Weight          959
# pH              235
# dtype: int64

# %%
classification_normal_weight_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Peso normal']
classification_normal_weight_validation_ids = classification_normal_weight_validation["RecordID"]
classification_measurements_n_w_v = validation_X[validation_X["RecordID"].isin(classification_normal_weight_validation_ids)]
classification_measurements_n_w_v = classification_measurements_n_w_v.count() 
classification_measurements_n_w_v
# Out:
# RecordID       15072
# level_1        15072
# Time           15072
# ALP              211
# ALT              212
# AST              213
# Age            14538
# Albumin          166
# BUN             1106
# Bilirubin        220
# Cholesterol       26
# Creatinine      1109
# DiasABP        10203
# FiO2            2590
# GCS             4852
# Gender           314
# Glucose          997
# HCO3            1078
# HCT             1560
# HR             13918
# Height         14538
# ICUType          314
# K               1115
# Lactate          689
# MAP            10155
# MechVent        2619
# Mg              1097
# NIDiasABP       4913
# NIMAP           4877
# NISysABP        4919
# Na              1040
# PaCO2           2252
# PaO2            2249
# Platelets       1231
# RespRate        1931
# SaO2             923
# SysABP         10203
# Temp            6671
# TroponinI         25
# TroponinT        164
# Urine          11404
# WBC             1066
# Weight          8314
# pH              2402
# dtype: int64

# %%
classification_overweight_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Sobrepeso']
classification_overweight_validation_ids = classification_overweight_validation["RecordID"]
classification_measurements_o_w_v = validation_X[validation_X["RecordID"].isin(classification_overweight_validation_ids)]
classification_measurements_o_w_v = classification_measurements_o_w_v.count() 
classification_measurements_o_w_v
# Out:
# RecordID       20688
# level_1        20688
# Time           20688
# ALP              334
# ALT              340
# AST              341
# Age            19823
# Albumin          222
# BUN             1508
# Bilirubin        339
# Cholesterol       36
# Creatinine      1515
# DiasABP        14347
# FiO2            3544
# GCS             6052
# Gender           431
# Glucose         1279
# HCO3            1455
# HCT             2242
# HR             18886
# Height         19823
# ICUType          431
# K               1444
# Lactate          905
# MAP            14326
# MechVent        3567
# Mg              1522
# NIDiasABP       6167
# NIMAP           6078
# NISysABP        6177
# Na              1364
# PaCO2           3447
# PaO2            3443
# Platelets       1731
# RespRate        2413
# SaO2            1492
# SysABP         14348
# Temp           10323
# TroponinI         42
# TroponinT        162
# Urine          15596
# WBC             1486
# Weight         11410
# pH              3720
# dtype: int64

# %%
classification_obesity_grade1_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Obesidade grau 1']
classification_obesity_grade1_validation_ids = classification_obesity_grade1_validation["RecordID"]
classification_measurements_ob1_v = validation_X[validation_X["RecordID"].isin(classification_obesity_grade1_validation_ids)]
classification_measurements_ob1_v  = classification_measurements_ob1_v .count() 
classification_measurements_ob1_v
# Out:
# RecordID       13440
# level_1        13440
# Time           13440
# ALP              202
# ALT              207
# AST              209
# Age            12994
# Albumin          121
# BUN              971
# Bilirubin        204
# Cholesterol       17
# Creatinine       970
# DiasABP         9745
# FiO2            2355
# GCS             4003
# Gender           280
# Glucose          788
# HCO3             923
# HCT             1491
# HR             12400
# Height         12994
# ICUType          280
# K                901
# Lactate          650
# MAP             9734
# MechVent        2327
# Mg               978
# NIDiasABP       3997
# NIMAP           3924
# NISysABP        3999
# Na               852
# PaCO2           2462
# PaO2            2459
# Platelets       1120
# RespRate        1257
# SaO2            1033
# SysABP          9745
# Temp            6978
# TroponinI         22
# TroponinT        100
# Urine          10453
# WBC              957
# Weight          7703
# pH              2633
# dtype: int64

# %%
classification_obesity_grade2_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Obesidade grau 2']
classification_obesity_grade2_validation_ids = classification_obesity_grade2_validation["RecordID"]
classification_measurements_ob2_v = validation_X[validation_X["RecordID"].isin(classification_obesity_grade2_validation_ids)]
classification_measurements_ob2_v  = classification_measurements_ob2_v .count() 
classification_measurements_ob2_v
# Out:
# RecordID       5760
# level_1        5760
# Time           5760
# ALP              92
# ALT              91
# AST              92
# Age            5528
# Albumin          50
# BUN             425
# Bilirubin        93
# Cholesterol       5
# Creatinine      427
# DiasABP        4156
# FiO2           1067
# GCS            1622
# Gender          120
# Glucose         342
# HCO3            396
# HCT             665
# HR             5246
# Height         5528
# ICUType         120
# K               383
# Lactate         346
# MAP            4220
# MechVent       1051
# Mg              433
# NIDiasABP      1589
# NIMAP          1537
# NISysABP       1590
# Na              381
# PaCO2          1183
# PaO2           1181
# Platelets       484
# RespRate        451
# SaO2            528
# SysABP         4156
# Temp           3213
# TroponinI        13
# TroponinT        45
# Urine          4360
# WBC             407
# Weight         3325
# pH             1241
# dtype: int64

# %%
classification_obesity_grade3_validation = bmi_data_validation[bmi_data_validation["Classificacao"] == 'Obesidade grau 3']
classification_obesity_grade3_validation_ids = classification_obesity_grade3_validation["RecordID"]
classification_measurements_ob3_v = validation_X[validation_X["RecordID"].isin(classification_obesity_grade3_validation_ids)]
classification_measurements_ob3_v  = classification_measurements_ob3_v .count() 
classification_measurements_ob3_v
# Out:
# RecordID       4368
# level_1        4368
# Time           4368
# ALP              84
# ALT              83
# AST              83
# Age            4199
# Albumin          52
# BUN             337
# Bilirubin        88
# Cholesterol       5
# Creatinine      337
# DiasABP        3116
# FiO2            827
# GCS            1302
# Gender           91
# Glucose         298
# HCO3            326
# HCT             412
# HR             4026
# Height         4199
# ICUType          91
# K               333
# Lactate         257
# MAP            3140
# MechVent        864
# Mg              336
# NIDiasABP      1286
# NIMAP          1275
# NISysABP       1290
# Na              320
# PaCO2           768
# PaO2            769
# Platelets       334
# RespRate        460
# SaO2            321
# SysABP         3116
# Temp           1839
# TroponinI         9
# TroponinT        57
# Urine          3170
# WBC             306
# Weight         2529
# pH              790
# dtype: int64

# %%
df_columns = validation_X.columns
df_columns
# Out:
# Index(['RecordID', 'level_1', 'Time', 'ALP', 'ALT', 'AST', 'Age', 'Albumin',
#        'BUN', 'Bilirubin', 'Cholesterol', 'Creatinine', 'DiasABP', 'FiO2',
#        'GCS', 'Gender', 'Glucose', 'HCO3', 'HCT', 'HR', 'Height', 'ICUType',
#        'K', 'Lactate', 'MAP', 'MechVent', 'Mg', 'NIDiasABP', 'NIMAP',
#        'NISysABP', 'Na', 'PaCO2', 'PaO2', 'Platelets', 'RespRate', 'SaO2',
#        'SysABP', 'Temp', 'TroponinI', 'TroponinT', 'Urine', 'WBC', 'Weight',
#        'pH'],
#       dtype='object')

# %%
df_validation = pd.DataFrame(columns=df_columns)
df_validation_transpose = df_validation.T
df_validation_transpose["Female"] = female_gender_measurements_validation
df_validation_transpose["Male"] = male_gender_measurements_validation
df_validation_transpose["Undefined Gender"] = undefined_gender_measurements_validation
df_validation_transpose["ICUType 1"] = ICUType_1_measurements_validation
df_validation_transpose["ICUType 2"] = ICUType_2_measurements_validation
df_validation_transpose["ICUType 3"] = ICUType_3_measurements_validation
df_validation_transpose["ICUType 4"] = ICUType_4_measurements_validation
df_validation_transpose["Age 65+"] = age_65_and_above_measurements_validation
df_validation_transpose["Age 65-"] = age_under_65__measurements_validation
df_validation_transpose['Undefined Classification'] = classification_undefined_measurements_validation
df_validation_transpose['Low Weight'] = classification_measurements_l_w_v
df_validation_transpose['Normal Weight'] = classification_measurements_n_w_v
df_validation_transpose['Overweight'] = classification_measurements_o_w_v
df_validation_transpose['Obesity Grade 1'] = classification_measurements_ob1_v
df_validation_transpose['Obesity Grade 2'] = classification_measurements_ob2_v
df_validation_transpose['Obesity Grade 3'] = classification_measurements_ob3_v
df_validation_transpose = df_validation_transpose.drop('RecordID',axis=0)
df_validation_transpose = df_validation_transpose.drop('level_1',axis=0)
df_validation_transpose = df_validation_transpose.drop('Time',axis=0)
df_validation_transpose = df_validation_transpose.drop('Age',axis=0)
df_validation_transpose = df_validation_transpose.drop('Gender',axis=0)
df_validation_transpose = df_validation_transpose.drop('Height',axis=0)
df_validation_transpose = df_validation_transpose.drop('ICUType',axis=0)

#df_test_transpose.style.set_caption("Repeated Measurements per variable by demographics")

display(HTML("<h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Validation Set</h2>"))
df_validation_transpose
# Out:
# <h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Validation Set</h2>
#              Female   Male  Undefined Gender  ICUType 1  ICUType 2  ICUType 3  \
# ALP             698    854                 0        208        151        734
# ALT             710    880                 0        224        157        747
# AST             712    885                 0        223        158        747
# Albumin         498    630                 0        168         82        532
# BUN            2862   3775                 0       1027       1352       2387
# Bilirubin       715    875                 0        215        151        767
# Cholesterol      66     96                 0         83          6         35
# Creatinine     2875   3785                 0       1041       1357       2393
# DiasABP       20889  29059                 0       6039      16271      11189
# FiO2           6244   8099                 0       1613       3459       4621
# GCS           12708  16859                 0       3643       5363       8277
# Glucose        2730   3447                 0        964        948       2383
# HCO3           2830   3664                 0        989       1253       2398
# HCT            3654   5072                 0       1249       2316       2787
# HR            35658  47294                 0      12336      18937      27924
# K              3013   3852                 0       1174       1088       2574
# Lactate        1581   2150                 0        353        754       1311
# MAP           20765  28898                 0       6022      16308      11031
# MechVent       6148   7816                 0       1562       3347       4437
# Mg             2834   3729                 0       1019       1356       2266
# NIDiasABP     16945  21654                 0       6644       4634      17514
# NIMAP         16730  21383                 0       6577       4589      17236
# NISysABP      16961  21677                 0       6648       4642      17529
# Na             2879   3643                 0        986       1058       2456
# PaCO2          4326   6369                 0       1210       4242       2501
# PaO2           4324   6362                 0       1212       4233       2504
# Platelets      2833   3926                 0       1014       1733       2155
# RespRate       9728  11226                 0       4373        725       9328
# SaO2           1481   2267                 0        687       2222        386
# SysABP        20890  29060                 0       6040      16271      11190
# Temp          13912  20242                 0       4372      11793       8961
# TroponinI        63     97                 0         50         20         58
# TroponinT       433    563                 0        304         58        441
# Urine         27531  36053                 0       7778      17521      19017
# WBC            2628   3519                 0        914       1405       2071
# Weight        21836  27453                 0       6617      10782      20468
# pH             4475   6755                 0       1227       4684       2542
#
#              ICUType 4  Age 65+  Age 65-  Undefined Classification  \
# ALP                459      678      874                       766
# ALT                462      691      899                       795
# AST                469      696      901                       797
# Albumin            346      510      618                       596
# BUN               1871     3491     3146                      3049
# Bilirubin          457      694      896                       788
# Cholesterol         38       93       69                        78
# Creatinine        1869     3499     3161                      3065
# DiasABP          16449    27387    22561                     17056
# FiO2              4650     7866     6477                      6016
# GCS              12284    15262    14305                     14505
# Glucose           1882     3200     2977                      3033
# HCO3              1854     3394     3100                      3027
# HCT               2374     4714     4012                      3652
# HR               23755    44929    38023                     38266
# K                 2029     3578     3287                      3332
# Lactate           1313     1824     1907                      1440
# MAP              16302    27251    22412                     16818
# MechVent          4618     7380     6584                      5577
# Mg                1922     3474     3089                      2980
# NIDiasABP         9807    20732    17867                     22961
# NIMAP             9711    20477    17636                     22686
# NISysABP          9819    20751    17887                     22980
# Na                2022     3364     3158                      3188
# PaCO2             2742     5775     4920                      2963
# PaO2              2737     5767     4919                      2959
# Platelets         1857     3549     3210                      2804
# RespRate          6528    11438     9516                     14454
# SaO2               453     2272     1476                       512
# SysABP           16449    27389    22561                     17057
# Temp              9028    18924    15230                     11702
# TroponinI           32       99       61                        62
# TroponinT          193      686      310                       509
# Urine            19268    34870    28714                     27375
# WBC               1757     3222     2925                      2696
# Weight           11422    27104    22185                     23189
# pH                2777     6088     5142                      3021
#
#              Low Weight  Normal Weight  Overweight  Obesity Grade 1  \
# ALP                  22            211         334              202
# ALT                  21            212         340              207
# AST                  21            213         341              209
# Albumin              17            166         222              121
# BUN                 122           1106        1508              971
# Bilirubin            21            220         339              204
# Cholesterol           2             26          36               17
# Creatinine          122           1109        1515              970
# DiasABP             992          10203       14347             9745
# FiO2                259           2590        3544             2355
# GCS                 537           4852        6052             4003
# Glucose             106            997        1279              788
# HCO3                119           1078        1455              923
# HCT                 156           1560        2242             1491
# HR                 1518          13918       18886            12400
# K                   119           1115        1444              901
# Lactate              87            689         905              650
# MAP                 992          10155       14326             9734
# MechVent            294           2619        3567             2327
# Mg                  112           1097        1522              978
# NIDiasABP           588           4913        6167             3997
# NIMAP               583           4877        6078             3924
# NISysABP            588           4919        6177             3999
# Na                  118           1040        1364              852
# PaCO2               221           2252        3447             2462
# PaO2                222           2249        3443             2459
# Platelets           123           1231        1731             1120
# RespRate            227           1931        2413             1257
# SaO2                107            923        1492             1033
# SysABP              992          10203       14348             9745
# Temp                716           6671       10323             6978
# TroponinI             2             25          42               22
# TroponinT            20            164         162              100
# Urine              1234          11404       15596            10453
# WBC                 113           1066        1486              957
# Weight              959           8314       11410             7703
# pH                  235           2402        3720             2633
#
#              Obesity Grade 2  Obesity Grade 3
# ALP                       92               84
# ALT                       91               83
# AST                       92               83
# Albumin                   50               52
# BUN                      425              337
# Bilirubin                 93               88
# Cholesterol                5                5
# Creatinine               427              337
# DiasABP                 4156             3116
# FiO2                    1067              827
# GCS                     1622             1302
# Glucose                  342              298
# HCO3                     396              326
# HCT                      665              412
# HR                      5246             4026
# K                        383              333
# Lactate                  346              257
# MAP                     4220             3140
# MechVent                1051              864
# Mg                       433              336
# NIDiasABP               1589             1286
# NIMAP                   1537             1275
# NISysABP                1590             1290
# Na                       381              320
# PaCO2                   1183              768
# PaO2                    1181              769
# Platelets                484              334
# RespRate                 451              460
# SaO2                     528              321
# SysABP                  4156             3116
# Temp                    3213             1839
# TroponinI                 13                9
# TroponinT                 45               57
# Urine                   4360             3170
# WBC                      407              306
# Weight                  3325             2529
# pH                      1241              790

# %% [markdown]
# <h3> Test data</h3>

# %% [markdown]
# <h4>Loading test dataset</h4>

# %%
test_X = physionet2012_dataset['test_X']

# %%
var1 = test_X.count()
var1
# Out:
# RecordID       115152
# level_1        115152
# Time           115152
# ALP              1944
# ALT              1999
# AST              1994
# Age            108312
# Albumin          1502
# BUN              8365
# Bilirubin        2014
# Cholesterol       191
# Creatinine       8391
# DiasABP         63534
# FiO2            18112
# GCS             36377
# Gender           2399
# Glucose          7922
# HCO3             8187
# HCT             10953
# HR             103802
# Height         108312
# ICUType          2399
# K                8758
# Lactate          4854
# MAP             63246
# MechVent        17366
# Mg               8162
# NIDiasABP       47316
# NIMAP           46623
# NISysABP        47373
# Na               8190
# PaCO2           13568
# PaO2            13525
# Platelets        8567
# RespRate        28588
# SaO2             4801
# SysABP          63542
# Temp            42701
# TroponinI         227
# TroponinT        1251
# Urine           79544
# WBC              7871
# Weight          59735
# pH              14154
# dtype: int64

# %%
test_female_gender = test_X[test_X['Gender'] == 0.0]
test_female_gender_ids = test_female_gender["RecordID"]
female_gender_measurements_test = test_X[test_X["RecordID"].isin(test_female_gender_ids)]
female_gender_measurements_test = female_gender_measurements_test.count()
female_gender_measurements_test
# Out:
# RecordID       49296
# level_1        49296
# Time           49296
# ALP              839
# ALT              865
# AST              863
# Age            46458
# Albumin          655
# BUN             3579
# Bilirubin        871
# Cholesterol       79
# Creatinine      3591
# DiasABP        26181
# FiO2            7581
# GCS            15786
# Gender          1027
# Glucose         3444
# HCO3            3521
# HCT             4571
# HR             44622
# Height         46458
# ICUType         1027
# K               3793
# Lactate         2083
# MAP            26041
# MechVent        7463
# Mg              3498
# NIDiasABP      21300
# NIMAP          20968
# NISysABP       21326
# Na              3560
# PaCO2           5439
# PaO2            5414
# Platelets       3583
# RespRate       13498
# SaO2            1813
# SysABP         26183
# Temp           17620
# TroponinI        116
# TroponinT        512
# Urine          34650
# WBC             3331
# Weight         26215
# pH              5652
# dtype: int64

# %%
test_male_gender = test_X[test_X['Gender'] == 1.0]
test_male_gender_ids = test_male_gender["RecordID"]
male_gender_measurements_test = test_X[test_X["RecordID"].isin(test_male_gender_ids)]
male_gender_measurements_test = male_gender_measurements_test.count()
male_gender_measurements_test
# Out:
# RecordID       65760
# level_1        65760
# Time           65760
# ALP             1103
# ALT             1132
# AST             1129
# Age            61759
# Albumin          844
# BUN             4773
# Bilirubin       1141
# Cholesterol      112
# Creatinine      4787
# DiasABP        37305
# FiO2           10511
# GCS            20568
# Gender          1370
# Glucose         4465
# HCO3            4653
# HCT             6371
# HR             59086
# Height         61759
# ICUType         1370
# K               4952
# Lactate         2745
# MAP            37157
# MechVent        9880
# Mg              4653
# NIDiasABP      25977
# NIMAP          25616
# NISysABP       26008
# Na              4617
# PaCO2           8098
# PaO2            8080
# Platelets       4972
# RespRate       15090
# SaO2            2986
# SysABP         37311
# Temp           25043
# TroponinI        111
# TroponinT        737
# Urine          44836
# WBC             4529
# Weight         33430
# pH              8471
# dtype: int64

# %%
test_undefined_gender = test_X[test_X['Gender'] == -1.0]
test_undefined_gender_ids = test_undefined_gender["RecordID"]
undefined_gender_measurements_test = test_X[test_X["RecordID"].isin(test_undefined_gender_ids)]
undefined_gender_measurements_test = undefined_gender_measurements_test.count()
undefined_gender_measurements_test
# Out:
# RecordID       96
# level_1        96
# Time           96
# ALP             2
# ALT             2
# AST             2
# Age            95
# Albumin         3
# BUN            13
# Bilirubin       2
# Cholesterol     0
# Creatinine     13
# DiasABP        48
# FiO2           20
# GCS            23
# Gender          2
# Glucose        13
# HCO3           13
# HCT            11
# HR             94
# Height         95
# ICUType         2
# K              13
# Lactate        26
# MAP            48
# MechVent       23
# Mg             11
# NIDiasABP      39
# NIMAP          39
# NISysABP       39
# Na             13
# PaCO2          31
# PaO2           31
# Platelets      12
# RespRate        0
# SaO2            2
# SysABP         48
# Temp           38
# TroponinI       0
# TroponinT       2
# Urine          58
# WBC            11
# Weight         90
# pH             31
# dtype: int64

# %%
test_ICUType_1 = test_X[test_X['ICUType'] == 1.0]
test_ICUType_1 = test_ICUType_1[test_ICUType_1['Time'] == 0.0]
test_ICUType_1_ids = test_ICUType_1['RecordID']
ICUType_1_measurements_test = test_X[test_X['RecordID'].isin(test_ICUType_1_ids)]
ICUType_1_measurements_test = ICUType_1_measurements_test.count()
ICUType_1_measurements_test
# Out:
# RecordID       17904
# level_1        17904
# Time           17904
# ALP              264
# ALT              281
# AST              281
# Age            16512
# Albumin          196
# BUN             1298
# Bilirubin        273
# Cholesterol      112
# Creatinine      1314
# DiasABP         7493
# FiO2            1985
# GCS             4697
# Gender           373
# Glucose         1254
# HCO3            1261
# HCT             1529
# HR             15778
# Height         16512
# ICUType          373
# K               1504
# Lactate          386
# MAP             7500
# MechVent        1785
# Mg              1283
# NIDiasABP       8537
# NIMAP           8497
# NISysABP        8543
# Na              1261
# PaCO2           1484
# PaO2            1484
# Platelets       1284
# RespRate        6845
# SaO2             946
# SysABP          7493
# Temp            5284
# TroponinI         44
# TroponinT        420
# Urine          10274
# WBC             1184
# Weight          7622
# pH              1513
# dtype: int64

# %%
test_ICUType_2 = test_X[test_X['ICUType'] == 2.0]
test_ICUType_2 = test_ICUType_2[test_ICUType_2['Time'] == 0.0]
test_ICUType_2_ids = test_ICUType_2['RecordID']
ICUType_2_measurements_test = test_X[test_X['RecordID'].isin(test_ICUType_2_ids)]
ICUType_2_measurements_test = ICUType_2_measurements_test.count()
ICUType_2_measurements_test
# Out:
# RecordID       25104
# level_1        25104
# Time           25104
# ALP              200
# ALT              203
# AST              202
# Age            24226
# Albumin          131
# BUN             1603
# Bilirubin        202
# Cholesterol        5
# Creatinine      1603
# DiasABP        19768
# FiO2            4359
# GCS             6672
# Gender           523
# Glucose         1162
# HCO3            1467
# HCT             2669
# HR             23009
# Height         24226
# ICUType          523
# K               1314
# Lactate          880
# MAP            19765
# MechVent        4364
# Mg              1565
# NIDiasABP       5352
# NIMAP           5305
# NISysABP        5365
# Na              1220
# PaCO2           5151
# PaO2            5129
# Platelets       2020
# RespRate        1147
# SaO2            2732
# SysABP         19769
# Temp           14593
# TroponinI         32
# TroponinT         52
# Urine          21022
# WBC             1689
# Weight         12471
# pH              5601
# dtype: int64

# %%
test_ICUType_3 = test_X[test_X['ICUType'] == 3.0]
test_ICUType_3 = test_ICUType_3[test_ICUType_3['Time'] == 0.0]
test_ICUType_3_ids = test_ICUType_3['RecordID']
ICUType_3_measurements_test = test_X[test_X['RecordID'].isin(test_ICUType_3_ids)]
ICUType_3_measurements_test = ICUType_3_measurements_test.count()
ICUType_3_measurements_test
# Out:
# RecordID       40560
# level_1        40560
# Time           40560
# ALP              891
# ALT              915
# AST              916
# Age            37491
# Albumin          706
# BUN             3087
# Bilirubin        948
# Cholesterol       35
# Creatinine      3095
# DiasABP        14910
# FiO2            5795
# GCS            10856
# Gender           845
# Glucose         3111
# HCO3            3103
# HCT             3657
# HR             36069
# Height         37491
# ICUType          845
# K               3351
# Lactate         1642
# MAP            14753
# MechVent        5424
# Mg              2901
# NIDiasABP      22417
# NIMAP          21991
# NISysABP       22442
# Na              3181
# PaCO2           3187
# PaO2            3186
# Platelets       2838
# RespRate       12631
# SaO2             541
# SysABP         14914
# Temp           11656
# TroponinI        103
# TroponinT        570
# Urine          24252
# WBC             2715
# Weight         25844
# pH              3232
# dtype: int64

# %%
test_ICUType_4 = test_X[test_X['ICUType'] == 4.0]
test_ICUType_4 = test_ICUType_4[test_ICUType_4['Time'] == 0.0]
test_ICUType_4_ids = test_ICUType_4['RecordID']
ICUType_4_measurements_test = test_X[test_X['RecordID'].isin(test_ICUType_4_ids)]
ICUType_4_measurements_test = ICUType_4_measurements_test.count()
ICUType_4_measurements_test
# Out:
# RecordID       31584
# level_1        31584
# Time           31584
# ALP              589
# ALT              600
# AST              595
# Age            30083
# Albumin          469
# BUN             2377
# Bilirubin        591
# Cholesterol       39
# Creatinine      2379
# DiasABP        21363
# FiO2            5973
# GCS            14152
# Gender           658
# Glucose         2395
# HCO3            2356
# HCT             3098
# HR             28946
# Height         30083
# ICUType          658
# K               2589
# Lactate         1946
# MAP            21228
# MechVent        5793
# Mg              2413
# NIDiasABP      11010
# NIMAP          10830
# NISysABP       11023
# Na              2528
# PaCO2           3746
# PaO2            3726
# Platelets       2425
# RespRate        7965
# SaO2             582
# SysABP         21366
# Temp           11168
# TroponinI         48
# TroponinT        209
# Urine          23996
# WBC             2283
# Weight         13798
# pH              3808
# dtype: int64

# %%
age_65_and_above_test= test_X[test_X['Age'] >= 65]
age_65_and_above_test = age_65_and_above_test[age_65_and_above_test['Time'] == 0.0]
age_65_and_above_test_ids = age_65_and_above_test['RecordID']
age_65_and_above_measurements_test= test_X[test_X['RecordID'].isin(age_65_and_above_test_ids)]
age_65_and_above_measurements_test = age_65_and_above_measurements_test.count()
age_65_and_above_measurements_test
# Out:
# RecordID       61776
# level_1        61776
# Time           61776
# ALP              851
# ALT              876
# AST              879
# Age            58330
# Albumin          712
# BUN             4404
# Bilirubin        888
# Cholesterol      122
# Creatinine      4420
# DiasABP        35307
# FiO2            9862
# GCS            19013
# Gender          1287
# Glucose         4116
# HCO3            4303
# HCT             5855
# HR             55988
# Height         58330
# ICUType         1287
# K               4585
# Lactate         2510
# MAP            35200
# MechVent        9386
# Mg              4311
# NIDiasABP      24557
# NIMAP          24300
# NISysABP       24587
# Na              4244
# PaCO2           7601
# PaO2            7583
# Platelets       4543
# RespRate       15325
# SaO2            2976
# SysABP         35308
# Temp           24044
# TroponinI        149
# TroponinT        845
# Urine          44695
# WBC             4161
# Weight         31285
# pH              7951
# dtype: int64

# %%
age_under_65_test = test_X[test_X['Age'] < 65]
age_under_65_test = age_under_65_test[age_under_65_test['Time'] == 0.0]
age_under_65_test_ids = age_under_65_test["RecordID"]
age_under_65_measurements_test = test_X[test_X["RecordID"].isin(age_under_65_test_ids)]
age_under_65_measurements_test = age_under_65_measurements_test.count()
age_under_65_measurements_test
# Out:
# RecordID       53376
# level_1        53376
# Time           53376
# ALP             1093
# ALT             1123
# AST             1115
# Age            49982
# Albumin          790
# BUN             3961
# Bilirubin       1126
# Cholesterol       69
# Creatinine      3971
# DiasABP        28227
# FiO2            8250
# GCS            17364
# Gender          1112
# Glucose         3806
# HCO3            3884
# HCT             5098
# HR             47814
# Height         49982
# ICUType         1112
# K               4173
# Lactate         2344
# MAP            28046
# MechVent        7980
# Mg              3851
# NIDiasABP      22759
# NIMAP          22323
# NISysABP       22786
# Na              3946
# PaCO2           5967
# PaO2            5942
# Platelets       4024
# RespRate       13263
# SaO2            1825
# SysABP         28234
# Temp           18657
# TroponinI         78
# TroponinT        406
# Urine          34849
# WBC             3710
# Weight         28450
# pH              6203
# dtype: int64

# %%
filtered_test_X = test_X[(test_X['Height'] != -1) & (test_X['Weight'] != -1) & (test_X['Height'].notna()) & (test_X['Weight'].notna())]

# %%
filtered_test_X_meters = filtered_test_X.copy()
filtered_test_X_meters['Height'] = filtered_test_X['Height'] / 100 # Converting Height from cm to meters
filtered_test_X_meters['Height']
# Out:
# 528       1.575
# 549       1.575
# 550       1.575
# 551       1.575
# 552       1.575
#           ...
# 574939    1.702
# 574940    1.702
# 574941    1.702
# 574942    1.702
# 574943    1.702
# Name: Height, Length: 31418, dtype: float64

# %%
bmi_data_test = filtered_test_X_meters
bmi_data_test["BMI"] = round(filtered_test_X_meters["Weight"] / (filtered_test_X_meters["Height"] ** 2), 1)
bmi_data_test["Classificacao"] = bmi_data_test["BMI"].apply(classify_BMI)
bmi_data_test.head()
# Out:
#      RecordID  level_1  Time  ALP  ALT  AST   Age  Albumin  BUN  Bilirubin  \
# 528    132567        0   0.0  NaN  NaN  NaN  71.0      NaN  NaN        NaN
# 549    132567       21  21.0  NaN  NaN  NaN  71.0      NaN  NaN        NaN
# 550    132567       22  22.0  NaN  NaN  NaN  71.0      NaN  NaN        NaN
# 551    132567       23  23.0  NaN  NaN  NaN  71.0      NaN  NaN        NaN
# 552    132567       24  24.0  NaN  NaN  NaN  71.0      NaN  NaN        NaN
#
#      ...  SysABP  Temp  TroponinI  TroponinT  Urine  WBC  Weight    pH   BMI  \
# 528  ...   111.5  35.6        NaN        NaN    NaN  NaN    56.0  7.44  22.6
# 549  ...   110.0  37.5        NaN        NaN   15.0  NaN    55.8   NaN  22.5
# 550  ...   106.0  37.6        NaN        NaN   20.0  NaN    55.8   NaN  22.5
# 551  ...   129.0  37.7        NaN        NaN   30.0  NaN    55.8   NaN  22.5
# 552  ...    94.0  37.8        NaN        NaN   20.0  NaN    55.8   NaN  22.5
#
#      Classificacao
# 528    Peso normal
# 549    Peso normal
# 550    Peso normal
# 551    Peso normal
# 552    Peso normal
#
# [5 rows x 46 columns]

# %%
classification_undefined_test_ids = bmi_data_test["RecordID"]
classification_undefined_measurements_test = test_X[~test_X["RecordID"].isin(classification_undefined_test_ids)]
classification_undefined_measurements_test = classification_undefined_measurements_test.count()
classification_undefined_measurements_test
# Out:
# RecordID       54144
# level_1        54144
# Time           54144
# ALP              938
# ALT              960
# AST              960
# Age            49955
# Albumin          748
# BUN             3826
# Bilirubin        971
# Cholesterol       86
# Creatinine      3836
# DiasABP        22417
# FiO2            7459
# GCS            17840
# Gender          1128
# Glucose         3840
# HCO3            3815
# HCT             4696
# HR             47915
# Height         49955
# ICUType         1128
# K               4195
# Lactate         1976
# MAP            22255
# MechVent        6937
# Mg              3716
# NIDiasABP      27888
# NIMAP          27431
# NISysABP       27910
# Na              3998
# PaCO2           4057
# PaO2            4042
# Platelets       3593
# RespRate       18201
# SaO2             642
# SysABP         22422
# Temp           14692
# TroponinI         80
# TroponinT        636
# Urine          33995
# WBC             3449
# Weight         28317
# pH              4134
# dtype: int64

# %%
classification_low_weight_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Baixo peso']
classification_low_weight_test_ids = classification_low_weight_test["RecordID"]
classification_measurements_l_w_test = test_X[test_X["RecordID"].isin(classification_low_weight_test_ids)]
classification_measurements_l_w_test = classification_measurements_l_w_test.count() 
classification_measurements_l_w_test
# Out:
# RecordID       2256
# level_1        2256
# Time           2256
# ALP              40
# ALT              41
# AST              41
# Age            2135
# Albumin          24
# BUN             182
# Bilirubin        41
# Cholesterol       2
# Creatinine      183
# DiasABP        1508
# FiO2            419
# GCS             718
# Gender           47
# Glucose         179
# HCO3            180
# HCT             219
# HR             2056
# Height         2135
# ICUType          47
# K               192
# Lactate         101
# MAP            1498
# MechVent        373
# Mg              183
# NIDiasABP       734
# NIMAP           730
# NISysABP        739
# Na              176
# PaCO2           302
# PaO2            303
# Platelets       172
# RespRate        364
# SaO2            125
# SysABP         1508
# Temp            912
# TroponinI         9
# TroponinT        28
# Urine          1596
# WBC             161
# Weight         1144
# pH              319
# dtype: int64

# %%
classification_normal_weight_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Peso normal']
classification_normal_weight_test_ids = classification_normal_weight_test["RecordID"]
classification_measurements_n_w_test = test_X[test_X["RecordID"].isin(classification_normal_weight_test_ids)]
classification_measurements_n_w_test = classification_measurements_n_w_test.count() 
classification_measurements_n_w_test
# Out:
# RecordID       19488
# level_1        19488
# Time           19488
# ALP              305
# ALT              316
# AST              315
# Age            18575
# Albumin          228
# BUN             1387
# Bilirubin        309
# Cholesterol       40
# Creatinine      1390
# DiasABP        12664
# FiO2            3199
# GCS             6020
# Gender           406
# Glucose         1247
# HCO3            1346
# HCT             2002
# HR             17803
# Height         18575
# ICUType          406
# K               1394
# Lactate          782
# MAP            12613
# MechVent        3221
# Mg              1364
# NIDiasABP       6603
# NIMAP           6520
# NISysABP        6614
# Na              1282
# PaCO2           2836
# PaO2            2826
# Platelets       1561
# RespRate        3864
# SaO2            1254
# SysABP         12664
# Temp            8906
# TroponinI         60
# TroponinT        154
# Urine          14250
# WBC             1379
# Weight          9788
# pH              3035
# dtype: int64

# %%
classification_overweight_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Sobrepeso']
classification_overweight_test_ids = classification_overweight_test["RecordID"]
classification_measurements_o_w_test = test_X[test_X["RecordID"].isin(classification_overweight_test_ids)]
classification_measurements_o_w_test = classification_measurements_o_w_test.count() 
classification_measurements_o_w_test
# Out:
# RecordID       24720
# level_1        24720
# Time           24720
# ALP              381
# ALT              389
# AST              389
# Age            23684
# Albumin          286
# BUN             1800
# Bilirubin        391
# Cholesterol       29
# Creatinine      1809
# DiasABP        17680
# FiO2            4287
# GCS             7487
# Gender           515
# Glucose         1553
# HCO3            1719
# HCT             2612
# HR             22673
# Height         23684
# ICUType          515
# K               1722
# Lactate         1101
# MAP            17657
# MechVent        4235
# Mg              1759
# NIDiasABP       7015
# NIMAP           6949
# NISysABP        7029
# Na              1602
# PaCO2           4019
# PaO2            4005
# Platelets       2070
# RespRate        3579
# SaO2            1862
# SysABP         17681
# Temp           11818
# TroponinI         57
# TroponinT        219
# Urine          19012
# WBC             1811
# Weight         13489
# pH              4270
# dtype: int64

# %%
classification_obesity_grade1_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Obesidade grau 1']
classification_obesity_grade1_test_ids = classification_obesity_grade1_test["RecordID"]
classification_measurements_ob1_test = test_X[test_X["RecordID"].isin(classification_obesity_grade1_test_ids)]
classification_measurements_ob1_test = classification_measurements_ob1_test .count() 
classification_measurements_ob1_test
# Out:
# RecordID       16560
# level_1        16560
# Time           16560
# ALP              248
# ALT              255
# AST              252
# Age            16012
# Albumin          186
# BUN             1235
# Bilirubin        259
# Cholesterol       23
# Creatinine      1239
# DiasABP        12152
# FiO2            3103
# GCS             4894
# Gender           345
# Glucose         1054
# HCO3            1170
# HCT             1746
# HR             15261
# Height         16012
# ICUType          345
# K               1206
# Lactate          842
# MAP            12107
# MechVent        3135
# Mg              1202
# NIDiasABP       4443
# NIMAP           4400
# NISysABP        4450
# Na              1102
# PaCO2           3085
# PaO2            3076
# Platelets       1382
# RespRate        1897
# SaO2            1412
# SysABP         12153
# Temp            8689
# TroponinI         30
# TroponinT        152
# Urine          13077
# WBC             1210
# Weight          9132
# pH              3246
# dtype: int64

# %%
classification_obesity_grade2_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Obesidade grau 2']
classification_obesity_grade2_test_ids = classification_obesity_grade2_test["RecordID"]
classification_measurements_ob2_test = test_X[test_X["RecordID"].isin(classification_obesity_grade2_test_ids)]
classification_measurements_ob2_test = classification_measurements_ob2_test .count() 
classification_measurements_ob2_test
# Out:
# RecordID       7152
# level_1        7152
# Time           7152
# ALP             120
# ALT             125
# AST             125
# Age            6946
# Albumin          86
# BUN             567
# Bilirubin       127
# Cholesterol       8
# Creatinine      570
# DiasABP        5263
# FiO2           1552
# GCS            1950
# Gender          149
# Glucose         478
# HCO3            541
# HCT             831
# HR             6602
# Height         6946
# ICUType         149
# K               541
# Lactate         496
# MAP            5243
# MechVent       1468
# Mg              562
# NIDiasABP      1989
# NIMAP          1967
# NISysABP       1993
# Na              504
# PaCO2          1520
# PaO2           1513
# Platelets       657
# RespRate        645
# SaO2            696
# SysABP         5265
# Temp           3903
# TroponinI        14
# TroponinT        73
# Urine          5676
# WBC             567
# Weight         3880
# pH             1589
# dtype: int64

# %%
classification_obesity_grade3_test = bmi_data_test[bmi_data_test["Classificacao"] == 'Obesidade grau 3']
classification_obesity_grade3_test_ids = classification_obesity_grade3_test["RecordID"]
classification_measurements_ob3_test = test_X[test_X["RecordID"].isin(classification_obesity_grade3_test_ids)]
classification_measurements_ob3_test = classification_measurements_ob3_test .count() 
classification_measurements_ob3_test
# Out:
# RecordID       4992
# level_1        4992
# Time           4992
# ALP              97
# ALT             101
# AST             101
# Age            4810
# Albumin          68
# BUN             396
# Bilirubin       102
# Cholesterol      10
# Creatinine      395
# DiasABP        3421
# FiO2            990
# GCS            1303
# Gender          104
# Glucose         351
# HCO3            376
# HCT             543
# HR             4585
# Height         4810
# ICUType         104
# K               388
# Lactate         351
# MAP            3430
# MechVent        972
# Mg              387
# NIDiasABP      1358
# NIMAP          1329
# NISysABP       1360
# Na              353
# PaCO2           989
# PaO2            986
# Platelets       430
# RespRate        672
# SaO2            398
# SysABP         3422
# Temp           2537
# TroponinI         5
# TroponinT        51
# Urine          3906
# WBC             372
# Weight         2979
# pH             1019
# dtype: int64

# %%
df_columns = test_X.columns
df_columns
# Out:
# Index(['RecordID', 'level_1', 'Time', 'ALP', 'ALT', 'AST', 'Age', 'Albumin',
#        'BUN', 'Bilirubin', 'Cholesterol', 'Creatinine', 'DiasABP', 'FiO2',
#        'GCS', 'Gender', 'Glucose', 'HCO3', 'HCT', 'HR', 'Height', 'ICUType',
#        'K', 'Lactate', 'MAP', 'MechVent', 'Mg', 'NIDiasABP', 'NIMAP',
#        'NISysABP', 'Na', 'PaCO2', 'PaO2', 'Platelets', 'RespRate', 'SaO2',
#        'SysABP', 'Temp', 'TroponinI', 'TroponinT', 'Urine', 'WBC', 'Weight',
#        'pH'],
#       dtype='object')

# %%
df_test = pd.DataFrame(columns=df_columns)
df_test_transpose = df_test.T
df_test_transpose["Female"] = female_gender_measurements_test
df_test_transpose["Male"] = male_gender_measurements_test
df_test_transpose["Undefined Gender"] = undefined_gender_measurements_test
df_test_transpose["ICUType 1"] = ICUType_1_measurements_test
df_test_transpose["ICUType 2"] = ICUType_2_measurements_test
df_test_transpose["ICUType 3"] = ICUType_3_measurements_test
df_test_transpose["ICUType 4"] = ICUType_4_measurements_test
df_test_transpose["Age 65+"] = age_65_and_above_measurements_test
df_test_transpose["Age 65-"] = age_under_65_measurements_test
df_test_transpose['Undefined Classification'] = classification_undefined_measurements_test
df_test_transpose['Low Weight'] = classification_measurements_l_w_test 
df_test_transpose['Normal Weight'] = classification_measurements_n_w_test
df_test_transpose['Overweight'] = classification_measurements_o_w_test
df_test_transpose['Obesity Grade 1'] = classification_measurements_ob1_test 
df_test_transpose['Obesity Grade 2'] = classification_measurements_ob2_test
df_test_transpose['Obesity Grade 3'] = classification_measurements_ob3_test
df_test_transpose = df_test_transpose.drop('RecordID',axis=0)
df_test_transpose = df_test_transpose.drop('level_1',axis=0)
df_test_transpose = df_test_transpose.drop('Time',axis=0)
df_test_transpose = df_test_transpose.drop('Age',axis=0)
df_test_transpose = df_test_transpose.drop('Gender',axis=0)
df_test_transpose = df_test_transpose.drop('Height',axis=0)
df_test_transpose = df_test_transpose.drop('ICUType',axis=0)

#df_test_transpose.style.set_caption("Repeated Measurements per variable by demographics")

display(HTML("<h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Test Set</h2>"))
df_test_transpose
# Out:
# <h2 style='text-align: center; font-size: 24px; font-weight: bold;'>Repeated Measurements per Variable by Demographics - Test Set</h2>
#              Female   Male  Undefined Gender  ICUType 1  ICUType 2  ICUType 3  \
# ALP             839   1103                 2        264        200        891
# ALT             865   1132                 2        281        203        915
# AST             863   1129                 2        281        202        916
# Albumin         655    844                 3        196        131        706
# BUN            3579   4773                13       1298       1603       3087
# Bilirubin       871   1141                 2        273        202        948
# Cholesterol      79    112                 0        112          5         35
# Creatinine     3591   4787                13       1314       1603       3095
# DiasABP       26181  37305                48       7493      19768      14910
# FiO2           7581  10511                20       1985       4359       5795
# GCS           15786  20568                23       4697       6672      10856
# Glucose        3444   4465                13       1254       1162       3111
# HCO3           3521   4653                13       1261       1467       3103
# HCT            4571   6371                11       1529       2669       3657
# HR            44622  59086                94      15778      23009      36069
# K              3793   4952                13       1504       1314       3351
# Lactate        2083   2745                26        386        880       1642
# MAP           26041  37157                48       7500      19765      14753
# MechVent       7463   9880                23       1785       4364       5424
# Mg             3498   4653                11       1283       1565       2901
# NIDiasABP     21300  25977                39       8537       5352      22417
# NIMAP         20968  25616                39       8497       5305      21991
# NISysABP      21326  26008                39       8543       5365      22442
# Na             3560   4617                13       1261       1220       3181
# PaCO2          5439   8098                31       1484       5151       3187
# PaO2           5414   8080                31       1484       5129       3186
# Platelets      3583   4972                12       1284       2020       2838
# RespRate      13498  15090                 0       6845       1147      12631
# SaO2           1813   2986                 2        946       2732        541
# SysABP        26183  37311                48       7493      19769      14914
# Temp          17620  25043                38       5284      14593      11656
# TroponinI       116    111                 0         44         32        103
# TroponinT       512    737                 2        420         52        570
# Urine         34650  44836                58      10274      21022      24252
# WBC            3331   4529                11       1184       1689       2715
# Weight        26215  33430                90       7622      12471      25844
# pH             5652   8471                31       1513       5601       3232
#
#              ICUType 4  Age 65+  Age 65-  Undefined Classification  \
# ALP                589      851     1093                       938
# ALT                600      876     1123                       960
# AST                595      879     1115                       960
# Albumin            469      712      790                       748
# BUN               2377     4404     3961                      3826
# Bilirubin          591      888     1126                       971
# Cholesterol         39      122       69                        86
# Creatinine        2379     4420     3971                      3836
# DiasABP          21363    35307    28227                     22417
# FiO2              5973     9862     8250                      7459
# GCS              14152    19013    17364                     17840
# Glucose           2395     4116     3806                      3840
# HCO3              2356     4303     3884                      3815
# HCT               3098     5855     5098                      4696
# HR               28946    55988    47814                     47915
# K                 2589     4585     4173                      4195
# Lactate           1946     2510     2344                      1976
# MAP              21228    35200    28046                     22255
# MechVent          5793     9386     7980                      6937
# Mg                2413     4311     3851                      3716
# NIDiasABP        11010    24557    22759                     27888
# NIMAP            10830    24300    22323                     27431
# NISysABP         11023    24587    22786                     27910
# Na                2528     4244     3946                      3998
# PaCO2             3746     7601     5967                      4057
# PaO2              3726     7583     5942                      4042
# Platelets         2425     4543     4024                      3593
# RespRate          7965    15325    13263                     18201
# SaO2               582     2976     1825                       642
# SysABP           21366    35308    28234                     22422
# Temp             11168    24044    18657                     14692
# TroponinI           48      149       78                        80
# TroponinT          209      845      406                       636
# Urine            23996    44695    34849                     33995
# WBC               2283     4161     3710                      3449
# Weight           13798    31285    28450                     28317
# pH                3808     7951     6203                      4134
#
#              Low Weight  Normal Weight  Overweight  Obesity Grade 1  \
# ALP                  40            305         381              248
# ALT                  41            316         389              255
# AST                  41            315         389              252
# Albumin              24            228         286              186
# BUN                 182           1387        1800             1235
# Bilirubin            41            309         391              259
# Cholesterol           2             40          29               23
# Creatinine          183           1390        1809             1239
# DiasABP            1508          12664       17680            12152
# FiO2                419           3199        4287             3103
# GCS                 718           6020        7487             4894
# Glucose             179           1247        1553             1054
# HCO3                180           1346        1719             1170
# HCT                 219           2002        2612             1746
# HR                 2056          17803       22673            15261
# K                   192           1394        1722             1206
# Lactate             101            782        1101              842
# MAP                1498          12613       17657            12107
# MechVent            373           3221        4235             3135
# Mg                  183           1364        1759             1202
# NIDiasABP           734           6603        7015             4443
# NIMAP               730           6520        6949             4400
# NISysABP            739           6614        7029             4450
# Na                  176           1282        1602             1102
# PaCO2               302           2836        4019             3085
# PaO2                303           2826        4005             3076
# Platelets           172           1561        2070             1382
# RespRate            364           3864        3579             1897
# SaO2                125           1254        1862             1412
# SysABP             1508          12664       17681            12153
# Temp                912           8906       11818             8689
# TroponinI             9             60          57               30
# TroponinT            28            154         219              152
# Urine              1596          14250       19012            13077
# WBC                 161           1379        1811             1210
# Weight             1144           9788       13489             9132
# pH                  319           3035        4270             3246
#
#              Obesity Grade 2  Obesity Grade 3
# ALP                      120               97
# ALT                      125              101
# AST                      125              101
# Albumin                   86               68
# BUN                      567              396
# Bilirubin                127              102
# Cholesterol                8               10
# Creatinine               570              395
# DiasABP                 5263             3421
# FiO2                    1552              990
# GCS                     1950             1303
# Glucose                  478              351
# HCO3                     541              376
# HCT                      831              543
# HR                      6602             4585
# K                        541              388
# Lactate                  496              351
# MAP                     5243             3430
# MechVent                1468              972
# Mg                       562              387
# NIDiasABP               1989             1358
# NIMAP                   1967             1329
# NISysABP                1993             1360
# Na                       504              353
# PaCO2                   1520              989
# PaO2                    1513              986
# Platelets                657              430
# RespRate                 645              672
# SaO2                     696              398
# SysABP                  5265             3422
# Temp                    3903             2537
# TroponinI                 14                5
# TroponinT                 73               51
# Urine                   5676             3906
# WBC                      567              372
# Weight                  3880             2979
# pH                      1589             1019
